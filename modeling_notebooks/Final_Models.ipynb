# %%
from google.colab import drive
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, Activation
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
import tensorflow as tf
import numpy as np
import os 
from os import listdir
from random import sample
import pandas as pd
import random
np.random.seed(2)
np.random.RandomState(2)
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D
import cv2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
from google.colab.patches import cv2_imshow
from keras.applications.vgg16 import VGG16
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import ConfusionMatrixDisplay
from keras.models import load_model
import sklearn
from collections import Counter
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.applications import ResNet50

# %% [markdown]
# # A Note on File Paths

# %% [markdown]
# The below code was written in Google Colab due to the time required to model the data. This notebook was mounted on the Google Drive, on the code file paths reflect as such.
#
# Similarly named files, i.e. the original images saved down in a file called 'raw_dataset' should result in the code running without issues.
#
# If any guidance is required, users are encouraged to reach out via Github.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read in the image dataset.

# %%
data_path = '/content/drive/MyDrive/clothing_class/raw_dataset'
imseg_data_path_kmeans = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_kmeans'
imseg_data_path_kmeans3 = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_kmeans3'
imseg_data_path_contour = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_contour'
imseg_data_path_thresh = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_thresholding'

# %% [markdown]
# ## Read in CSV Files

# %%
clothes_df = pd.read_csv('/content/drive/MyDrive/clothing_class/dataset.csv')
resampled_df = pd.read_csv('/content/drive/MyDrive/clothing_class/data_resampled.csv')

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# The training image tensor data will be generated with the only augmentation being a rescaling, horizontal flip and rotation range of up to 40 degrees.
#
# The test set is rescaled.
#
# The dataset is split 80% to training, 20% to validation.

# %%
train_gen = ImageDataGenerator(
    rescale = 1/255,
    horizontal_flip = True,
    rotation_range = 40,
    validation_split=0.2,
)

test_gen = ImageDataGenerator(
    rescale = 1/255,
    validation_split=0.2,
)

# %% [markdown]
# ## Generate Image Tensor Data

# %% [markdown]
# The function below generates the tensor data that will be used for modeling.
#
# The function can be used for both training and testing sets, both garment and pattern modeling via the y-col argument, and reads in a specified dataset so that any of the segmented datasets can be selected.

# %%
def tensor_data(image_gen,data_frame,image_data_path,y_column,subset):
  tensor_data = image_gen.flow_from_dataframe(
  dataframe=data_frame,
  directory=image_data_path,
  x_col="file_name",
  y_col=y_column,
  batch_size=32,
  shuffle=False,
  color_mode='rgb',
  class_mode="categorical",
  subset=subset,
  random_state=2,
  seed=2,
  target_size=(224,224),
  validate_filenames=False)

  return tensor_data

# %% [markdown]
# ## Early Stop

# %% [markdown]
# Setting up an early stop regularization that will monitor increases in val loss metric.

# %%
early_stop = EarlyStopping(monitor='val_loss',
                           min_delta=0,
                           patience=15,
                           verbose=0,
                          )

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# This checkpoint feature will save down the best performing epoch, based on validation accuracy, that will provide a model on which predictions and evaluations can be performed.

# %%
def checkpoint(cp_name):
  return ModelCheckpoint(
                             monitor='val_accuracy', 
                             verbose=0, 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='auto',
                             filepath ='/content/drive/MyDrive/clothing_class/model_folder/'+str(cp_name)
                             )

# %% [markdown]
# ## Model Functions

# %% [markdown]
# Setting up a model function so that several other transfer learning models can be modeled on the data.

# %%
def model_function(tl_model,classes,alr):
  
    base_model = tl_model(include_top=False,
                     input_shape=(224, 224, 3),
                     weights='imagenet'
                     )
    for layer in base_model.layers:
        layer.trainable = False
    
    model = tf.keras.Sequential([
        
        base_model,
        
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.BatchNormalization(),
        
        tf.keras.layers.Dense(32,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Dense(256,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(256,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Dense(32,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(64,activation='relu'),

        tf.keras.layers.Dense(units=classes, activation='softmax')
    ])
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(learning_rate=alr),
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# ## Plot Functions

# %% [markdown]
# A function was built to plot the accuracy and validation accuracy at each epoch. The plot is displayed and saved down to a seperate folder.

# %%
def plot_accuracy(history,title,ext):
  plt.figure(figsize=(20,10))
  plt.plot(history.history['accuracy'], label='Train')
  plt.plot(history.history['val_accuracy'], label='Test')
  plt.ylabel('Accuracy',fontsize=20)
  plt.xlabel('Epochs',fontsize=20)
  plt.legend(prop={'size': 20})
  plt.title(title,fontsize=20)
  plt.savefig('/content/drive/MyDrive/clothing_class/jpegs/'+str(ext)+'_acc.jpeg',format='jpeg',bbox_inches='tight');

# %% [markdown]
# A function was built to plot the confusion matrix for each model, using the model predictions and the ground truths for the test set. The matrix is displayed and saved down to a seperate folder.

# %%
def plot_confusion_matrix(checkpoint,test_data,title,ext):
  preds = load_model('/content/drive/MyDrive/clothing_class/model_folder/'+checkpoint).predict(test_data)
  top_pred = np.argmax(preds,axis=1)

  labels = (test_data.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  predictions = [labels[k] for k in top_pred]

  label_true = [labels[k] for k in test_data.classes]

  fig,ax = plt.subplots(figsize=(20,10))
  ConfusionMatrixDisplay.from_predictions(label_true,
                                        predictions,cmap='Blues',
                                        ax=ax,
                                        )
  ax.set_xlabel('Predicted Label',fontsize=15)
  ax.set_ylabel('True Label',fontsize=15)
  plt.title(title,fontsize=20)
  plt.show()
  fig.savefig('/content/drive/MyDrive/clothing_class/jpegs/'+str(ext)+'_cm.jpeg',format='jpeg',bbox_inches='tight');

# %% [markdown]
# ## Function for Calculating Balanced Accuracy

# %% [markdown]
# A function was created to calculate the balanced accuracy for a given model and dataset.

# %%
def calculate_balanced_acc(model,dataframe,image_file,y_col):
  
  test_data = tensor_data(test_gen,dataframe,image_file,
                   y_col,'validation')
  
  preds = load_model('/content/drive/MyDrive/clothing_class/model_folder/'+model).predict(test_data)
  top_pred = np.argmax(preds,axis=1)

  labels = (test_data.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  predictions = [labels[k] for k in top_pred]

  label_true = [labels[k] for k in test_data.classes]

  return sklearn.metrics.balanced_accuracy_score(label_true,predictions)

# %% [markdown]
# ## Baselines

# %% [markdown]
# Reviewing the baseline values for these datasets to determine the accuracy level that must be surpassed to determine that a model performs better than merely choosing the majority class every time.

# %%
clothes_df['garment_label'].value_counts(normalize=True)
# Out:
# dress      0.139226
# sweater    0.136002
# coat       0.134484
# pants      0.129932
# tshirt     0.116654
# top        0.107360
# jacket     0.087253
# shorts     0.086495
# skirt      0.062595
# Name: garment_label, dtype: float64

# %% [markdown]
# The garment baseline for the dataset is ~14%.

# %%
clothes_df['pattern_label'].value_counts(normalize=True)
# Out:
# solid        0.567527
# horiz        0.161798
# polka        0.091426
# vertical     0.040971
# chevron      0.039264
# checkered    0.039264
# animal       0.036039
# paisley      0.023710
# Name: pattern_label, dtype: float64

# %% [markdown]
# The pattern baseline for the whole dataset is 56.7%.

# %%
resampled_df['pattern_label'].value_counts(normalize=True)
# Out:
# horiz        0.296386
# solid        0.207783
# polka        0.167477
# vertical     0.075052
# chevron      0.071925
# checkered    0.071925
# animal       0.066018
# paisley      0.043433
# Name: pattern_label, dtype: float64

# %% [markdown]
# The pattern baseline for the resampled dataset (which downsamples solid patterns) is ~30%. The resampled dataset will only be used for pattern modeling.

# %% [markdown]
# # Modeling

# %% [markdown]
# The purpose of the additional modeling below is to run models on another transfer learning architectures - ResNet50 - that is commonly used in the computer vision space, to see if model performace improves.

# %% [markdown]
# ## Transfer Learning Pattern Model - ResNet50

# %%
model_rp = model_function(tl_model=ResNet50,classes = 8,alr=.01)

train_data = tensor_data(train_gen,resampled_df,data_path,
                  'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,data_path,
                  'pattern_label','validation')

checkpoint_model_rp = checkpoint('model_rp')

history_model_rp = model_rp.fit(
    train_data,
    batch_size = 32,
    epochs=200,
    validation_data = test_data,
    callbacks = [checkpoint_model_rp,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_model_rp,'Patterns - No Segmentation, ResNet50: Accuracy',
              'res_pattern_transfer')

plot_confusion_matrix('model_rp',test_data,
                      'Patterns - No Segmentation, ResNet50: Confusion Matrix',
                      'res_pattern_transfer')
# Out:
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/200
# 72/72 [==============================] - ETA: 0s - loss: 1.8429 - accuracy: 0.3265INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rp/assets
# 72/72 [==============================] - 57s 732ms/step - loss: 1.8429 - accuracy: 0.3265 - val_loss: 2.0400 - val_accuracy: 0.2330
# Epoch 2/200
# 72/72 [==============================] - ETA: 0s - loss: 1.6687 - accuracy: 0.3969INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rp/assets
# 72/72 [==============================] - 58s 805ms/step - loss: 1.6687 - accuracy: 0.3969 - val_loss: 1.6074 - val_accuracy: 0.4296
# Epoch 3/200
# 72/72 [==============================] - 31s 431ms/step - loss: 1.6234 - accuracy: 0.4208 - val_loss: 1.6490 - val_accuracy: 0.3600
# Epoch 4/200
# 72/72 [==============================] - 31s 427ms/step - loss: 1.5907 - accuracy: 0.4260 - val_loss: 2.7208 - val_accuracy: 0.3113
# Epoch 5/200
# 72/72 [==============================] - 31s 435ms/step - loss: 1.5351 - accuracy: 0.4494 - val_loss: 1.5365 - val_accuracy: 0.4226
# Epoch 6/200
# 72/72 [==============================] - 31s 427ms/step - loss: 1.4916 - accuracy: 0.4733 - val_loss: 1.6211 - val_accuracy: 0.4243
# Epoch 7/200
# 72/72 [==============================] - ETA: 0s - loss: 1.4615 - accuracy: 0.4902INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_
# Epoch 24/200
# 72/72 [==============================] - 31s 426ms/step - loss: 1.2169 - accuracy: 0.6018 - val_loss: 1.9079 - val_accuracy: 0.3861
# Epoch 25/200
# 72/72 [==============================] - 31s 427ms/step - loss: 1.2473 - accuracy: 0.5801 - val_loss: 1.1948 - val_accuracy: 0.5791
# Epoch 26/200
# 72/72 [==============================] - 32s 442ms/step - loss: 1.2530 - accuracy: 0.5818 - val_loss: 2.7398 - val_accuracy: 0.3843
# Epoch 27/200
# 72/72 [==============================] - 31s 426ms/step - loss: 1.2284 - accuracy: 0.5801 - val_loss: 1.3405 - val_accuracy: 0.5200
# Epoch 28/200
# 72/72 [==============================] - 31s 427ms/step - loss: 1.2224 - accuracy: 0.5784 - val_loss: 1.4052 - val_accuracy: 0.5548
# Epoch 29/200
# 72/72 [==============================] - 31s 425ms/step - loss: 1.2252 - accuracy: 0.5849 - val_loss: 1.2939 - val_accuracy: 0.5530

# %%
calculate_balanced_acc('model_rp',resampled_df,data_path,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.4424288278548816

# %% [markdown]
# The ResNet50 model achieves a peak validation accuracy of 59.58%, and a balanced accuracy score of just 44.24%. This is much lower than the balanced accuracy achieved by the VGG16 model of ~80%.
#
# Within the test set, the model rarely predicts chevron stripe, and never predicts paisley or checkered.

# %% [markdown]
# ## Transfer Learning Garment Model - ResNet50

# %%
model_rg2 = model_function(tl_model=ResNet50,classes = 9,alr=.001)

train_data = tensor_data(train_gen,clothes_df,data_path,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,data_path,
                  'garment_label','validation')

checkpoint_model_rg2 = checkpoint('model_rg2')

history_model_rg2 = model_rg2.fit(
    train_data,
    batch_size = 32,
    epochs=200,
    validation_data = test_data,
    callbacks = [checkpoint_model_rg2,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_model_rg2,'Garments - No Segmentation, ResNet50 (learning rate =.001): Accuracy',
              'resnet_garment_transfer2')

plot_confusion_matrix('model_rg2',test_data,
                      'Garments - No Segmentation, ResNet50 (learning rate =.001): Confusion Matrix',
                      'resnet_garment_transfer2')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/200
# 132/132 [==============================] - ETA: 0s - loss: 2.1684 - accuracy: 0.1714INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rg2/assets
# 132/132 [==============================] - 82s 590ms/step - loss: 2.1684 - accuracy: 0.1714 - val_loss: 2.1969 - val_accuracy: 0.0987
# Epoch 2/200
# 132/132 [==============================] - ETA: 0s - loss: 2.0087 - accuracy: 0.2456INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rg2/assets
# 132/132 [==============================] - 83s 634ms/step - loss: 2.0087 - accuracy: 0.2456 - val_loss: 2.1870 - val_accuracy: 0.1926
# Epoch 3/200
# 132/132 [==============================] - ETA: 0s - loss: 1.8845 - accuracy: 0.2876INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rg2/assets
# 132/132 [==============================] - 77s 583ms/step - loss: 1.8845 - accuracy: 0.2876 - val_loss: 1.8255 - val_accuracy: 0.3397
# Epoch 4/200
# 132/132 [==============================] - ETA: 0s - loss: 1.8154 - accuracy: 0.3170INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rg2/assets
# 132/132 [==============================] - 82s 620ms/step - loss: 1.8154 - accuracy: 0.3170 - val_loss: 1.7656 - val_accuracy: 0.3435
# Epoch 5/200
# 132/132 [==============================] - ETA: 0s - loss: 1.7709 - accuracy: 0.3371INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_rg2/assets
# 132/132 [==============================] -
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.5760416026799406

# %% [markdown]
# The ResNet50 model achieves a peak validation accuracy of 59.58%, and balanced accuracy of 57.6%, which is again considerably lower than the 73.6% balanced accuracy score achieved by the VGG16 model.

# %% [markdown]
# # Tweaking Best Performing VGG16 Model

# %% [markdown]
# Making changes to learning rate, batch size to see if there is any improvement in performance.

# %% [markdown]
# ## VGG16 Model - No Segmentation, Less Augmentation, LR =.001 - Pattern

# %%
model_vp_nsa_001 = model_function(tl_model=VGG16,classes = 8,alr=.001)

train_data = tensor_data(train_gen,resampled_df,data_path,
                  'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,data_path,
                  'pattern_label','validation')

checkpoint_model_vp_nsa_001 = checkpoint('model_vp_nsa_001')

history_vp_nsa_001 = model_vp_nsa_001.fit(
    train_data,
    batch_size = 16,
    epochs=200,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_nsa_001,early_stop],
    validation_batch_size=16
)

plot_accuracy(history_vp_nsa_001,'Patterns - No Segmentation, Low Augmentation VGG16 (LR = .001) : Accuracy',
              'nsa_pattern_vgg16_.001')

plot_confusion_matrix('model_vp_nsa_001',test_data,
                      'Patterns - No Segmentation, Low Augmentation VGG16 (LR = .001): Confusion Matrix',
                      'nsa_pattern_vgg16_.001')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/200
# 72/72 [==============================] - ETA: 0s - loss: 1.8788 - accuracy: 0.3040INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 639s 9s/step - loss: 1.8788 - accuracy: 0.3040 - val_loss: 1.9381 - val_accuracy: 0.4017
# Epoch 2/200
# 72/72 [==============================] - ETA: 0s - loss: 1.5761 - accuracy: 0.4529INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 498ms/step - loss: 1.5761 - accuracy: 0.4529 - val_loss: 1.5860 - val_accuracy: 0.4661
# Epoch 3/200
# 72/72 [==============================] - ETA: 0s - loss: 1.3372 - accuracy: 0.5367INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 499ms/step - loss: 1.3372 - accuracy: 0.5367 - val_loss: 1.2739 - val_accuracy: 0.6070
# Epoch 4/200
# 72/72 [==============================] - ETA: 0s - loss: 1.1065 - accuracy: 0.6196INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 502ms/step - loss: 1.1065 - accuracy: 0.6196 - val_loss: 0.9418 - val_accuracy: 0.6974
# Epoch 5/200
# 72/72 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.6539INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 500ms/step - loss: 1.0238 - accuracy: 0.6539 - val_loss: 0.7847 - val_accuracy: 0.7530
# Epoch 6/200
# 72/72 [==============================] - ETA: 0s - loss: 0.9064 - accuracy: 0.7091INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 500ms/step - loss: 0.9064 - accuracy: 0.7091 - val_loss: 0.7012 - val_accuracy: 0.7826
# Epoch 7/200
# 72/72 [==============================] - ETA: 0s - loss: 0.8593 - accuracy: 0.7199INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s
[==============================] - ETA: 0s - loss: 0.4262 - accuracy: 0.8754INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 36s 503ms/step - loss: 0.4262 - accuracy: 0.8754 - val_loss: 0.5323 - val_accuracy: 0.8626
# Epoch 31/200
# 72/72 [==============================] - 31s 429ms/step - loss: 0.4104 - accuracy: 0.8710 - val_loss: 0.5558 - val_accuracy: 0.8365
# Epoch 32/200
# 72/72 [==============================] - 31s 424ms/step - loss: 0.4086 - accuracy: 0.8802 - val_loss: 0.5659 - val_accuracy: 0.8383
# Epoch 33/200
# 72/72 [==============================] - 31s 425ms/step - loss: 0.3995 - accuracy: 0.8806 - val_loss: 0.5390 - val_accuracy: 0.8400
# Epoch 34/200
# 72/72 [==============================] - 31s 423ms/step - loss: 0.4041 - accuracy: 0.8736 - val_loss: 0.5474 - val_accuracy: 0.8626
# Epoch 35/200
# 72/72 [==============================] - 31s 425ms/step - loss: 0.3921 - accuracy: 0.8828 - val_loss: 0.5649 - val_accuracy: 0.8522
# Epoch 36/200
# 72/72 [==============================] - 32s 446ms/step - loss: 0.3771 - accuracy: 0.8871 - val_loss: 0.5341 - val_accuracy: 0.8626
# Epoch 37/200
# 72/72 [==============================] - ETA: 0s - loss: 0.3715 - accuracy: 0.8875INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_001/assets
# 72/72 [==============================] - 35s 493ms/step - loss: 0.3715 - accuracy: 0.8875 - val_loss: 0.5344 - val_accuracy: 0.8661
# Epoch 38/200
# 72/72 [==============================] - 31s 426ms/step - loss: 0.3977 - accuracy: 0.8797 - val_loss: 0.5564 - val_accuracy: 0.8539
# Epoch 39/200
# 72/72 [==============================] - 31s 424ms/step - loss: 0.3753 - accuracy: 0.8819 - val_loss: 0.5613 - val_accuracy: 0.8400

# %%
calculate_balanced_acc('model_vp_nsa_001',resampled_df,data_path,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.8127468944587333

# %% [markdown]
# When fewer augmentations were applied to the non-segmented image data, and fed into the transfer learning model, performance relative to the model that was fed more augmented image data was fairly negilible.
#
# The confusion matrix appears very similar.

# %% [markdown]
# ## VGG16 Model - No Segmentation, Less Augmentation, LR =.001 - Garment

# %%
model_vg_nsa_001 = model_function(tl_model=VGG16,classes = 9,alr=.001)

train_data = tensor_data(train_gen,clothes_df,data_path,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,data_path,
                  'garment_label','validation')

checkpoint_model_vg_nsa_001 = checkpoint('model_vg_nsa_001')

history_vg_nsa_001 = model_vg_nsa_001.fit(
    train_data,
    batch_size = 16,
    epochs=200,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_nsa_001,early_stop],
    validation_batch_size=16
)

plot_accuracy(history_vg_nsa_001,'Garments - No Segmentation, Less Augmentation VGG16 (LR = .001): Accuracy',
              'nsa_garment_vgg16_001')

plot_confusion_matrix('model_vg_nsa_001',test_data,
                      'Garments - No Segmentation, Less Augmentation VGG16 (LR =.001): Confusion Matrix',
                      'nsa_garment_vgg16_001')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1
200
# 132/132 [==============================] - 56s 426ms/step - loss: 0.6531 - accuracy: 0.7812 - val_loss: 0.6378 - val_accuracy: 0.7884
# Epoch 37/200
# 132/132 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.7790INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa_001/assets
# 132/132 [==============================] - 66s 500ms/step - loss: 0.6556 - accuracy: 0.7790 - val_loss: 0.6060 - val_accuracy: 0.7960
# Epoch 38/200
# 132/132 [==============================] - 58s 436ms/step - loss: 0.6560 - accuracy: 0.7771 - val_loss: 0.5947 - val_accuracy: 0.7884
# Epoch 39/200
# 132/132 [==============================] - 56s 427ms/step - loss: 0.6245 - accuracy: 0.7923 - val_loss: 0.6198 - val_accuracy: 0.7903
# Epoch 40/200
# 132/132 [==============================] - 57s 433ms/step - loss: 0.6326 - accuracy: 0.7817 - val_loss: 0.6257 - val_accuracy: 0.7799
# Epoch 41/200
# 132/132 [==============================] - 56s 425ms/step - loss: 0.6438 - accuracy: 0.7826 - val_loss: 0.6025 - val_accuracy: 0.7875
# Epoch 42/200
# 132/132 [==============================] - 58s 437ms/step - loss: 0.6293 - accuracy: 0.7847 - val_loss: 0.6097 - val_accuracy: 0.7875
# Epoch 43/200
# 132/132 [==============================] - 56s 426ms/step - loss: 0.6294 - accuracy: 0.7921 - val_loss: 0.6057 - val_accuracy: 0.7894
# Epoch 44/200
# 132/132 [==============================] - 57s 432ms/step - loss: 0.6323 - accuracy: 0.7873 - val_loss: 0.6214 - val_accuracy: 0.7913
# Epoch 45/200
# 132/132 [==============================] - 58s 442ms/step - loss: 0.6243 - accuracy: 0.7952 - val_loss: 0.6556 - val_accuracy: 0.7837
# Epoch 46/200
# 132/132 [==============================] - 57s 428ms/step - loss: 0.6028 - accuracy: 0.7994 - val_loss: 0.6309 - val_accuracy: 0.7903
# Epoch 47/200
# 132/132 [==============================] - 56s 427ms/step - loss: 0.6216 - accuracy: 0.7930 - val_loss: 0.6241 - val_accuracy: 0.7846
# Epoch 48/200
# 132/132 [==============================] - 58s 436ms/step - loss: 0.5902 - accuracy: 0.8056 - val_loss: 0.6213 - val_accuracy: 0.7913
# Epoch 49/200
# 132/132 [==============================] - 57s 428ms/step - loss: 0.6020 - accuracy: 0.7963 - val_loss: 0.6141 - val_accuracy: 0.7837
# Epoch 50/200
# 132/132 [==============================] - 56s 427ms/step - loss: 0.5903 - accuracy: 0.7963 - val_loss: 0.6554 - val_accuracy: 0.7837
# Epoch 51/200
# 132/132 [==============================] - 57s 432ms/step - loss: 0.5741 - accuracy: 0.8061 - val_loss: 0.6211 - val_accuracy: 0.7960
# Epoch 52/200
# 132/132 [==============================] - 58s 437ms/step - loss: 0.5863 - accuracy: 0.8006 - val_loss: 0.6432 - val_accuracy: 0.7865
# Epoch 53/200
# 132/132 [==============================] - 56s 427ms/step - loss: 0.5733 - accuracy: 0.8006 - val_loss: 0.6280 - val_accuracy: 0.7932

# %%
calculate_balanced_acc('model_vg_nsa_001',clothes_df,data_path,'garment_label')
# Out:
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.7792425511594225

# %% [markdown]
# This model is the most accurate at identifying garments types, with 77.9% balanced accuracy.
