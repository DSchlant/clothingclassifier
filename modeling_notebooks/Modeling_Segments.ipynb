# %%
from google.colab import drive
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, Activation
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
import tensorflow as tf
import numpy as np
import os 
from os import listdir
from random import sample
import pandas as pd
import random
np.random.seed(2)
np.random.RandomState(2)
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalAveragePooling1D
import cv2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
from google.colab.patches import cv2_imshow
from keras.applications.vgg16 import VGG16
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import ConfusionMatrixDisplay
from keras.models import load_model
import sklearn
from collections import Counter

# %% [markdown]
# # A Note on File Paths

# %% [markdown]
# The below code was written in Google Colab due to the time required to model the data. This notebook was mounted on the Google Drive, on the code file paths reflect as such.
#
# Similarly named files, i.e. the original images saved down in a file called 'raw_dataset' should result in the code running without issues.
#
# If any guidance is required, users are encouraged to reach out via Github.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read in the image datasets.

# %%
data_path = '/content/drive/MyDrive/clothing_class/raw_dataset'
imseg_data_path_kmeans = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_kmeans'
imseg_data_path_kmeans3 = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_kmeans3'
imseg_data_path_contour = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_contour'
imseg_data_path_thresh = '/content/drive/MyDrive/clothing_class/segmented_images/cv2images_thresholding'

# %% [markdown]
# Setting up a list of the file names inside the image folder.

# %%
data_files = os.listdir(data_path)

# %% [markdown]
# ## Read in CSV Files

# %% [markdown]
# Full and resampled (downsampled solids) dataset read in below.

# %%
clothes_df = pd.read_csv('/content/drive/MyDrive/clothing_class/dataset.csv')
resampled_df = pd.read_csv('/content/drive/MyDrive/clothing_class/data_resampled.csv')

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# A series of image augmentations were added to enhance performance. The training images are rescaled, flipped vertically/horizontally, rotated up to 40 degrees, shifted in width, height, slant, and zoom. This aims to provide the model with additional versions of the image, and more data, on which to train.
#
# The test set is rescaled.
#
# The dataset is split 80% to training, 20% to validation.

# %%
aug_train_gen = ImageDataGenerator(
    rescale = 1/255,
    vertical_flip = True,
    horizontal_flip = True,
    rotation_range = 40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    validation_split=0.2
)

test_gen = ImageDataGenerator(
    rescale = 1/255,
    validation_split=0.2,
)

# %% [markdown]
# Creating a training generator that only flips horizontally and rotates the images.

# %%
la_train_gen = ImageDataGenerator(
    rescale = 1/255,
    horizontal_flip = True,
    rotation_range = 40,
    validation_split=0.2,
)

# %% [markdown]
# ## Generate Image Tensor Data

# %% [markdown]
# The function below generates the tensor data that will be used for modeling.
#
# The function can be used for both training and testing sets, both garment and pattern modeling via the y-col argument, and reads in a specified dataset so that any of the segmented datasets can be selected.

# %%
def tensor_data(image_gen,data_frame,image_data_path,y_column,subset):
  tensor_data = image_gen.flow_from_dataframe(
  dataframe=data_frame,
  directory=image_data_path,
  x_col="file_name",
  y_col=y_column,
  batch_size=32,
  shuffle=False,
  color_mode='rgb',
  class_mode="categorical",
  subset=subset,
  random_state=2,
  seed=2,
  target_size=(224,224),
  validate_filenames=False)

  return tensor_data

# %% [markdown]
# ## Early Stop

# %% [markdown]
# Initializing an early stop regularization that will monitor increases in val loss metric.

# %%
early_stop = EarlyStopping(monitor='val_loss',
                           min_delta=0,
                           patience=5,
                           verbose=0,
                          )

# %% [markdown]
# ## Checkpoint

# %% [markdown]
# This checkpoint feature will save down the best performing epoch, based on validation accuracy, that will provide a model on which predictions and evaluations can be performed.

# %%
def checkpoint(cp_name):
  return ModelCheckpoint(
                             monitor='val_accuracy', 
                             verbose=0, 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='auto',
                             filepath ='/content/drive/MyDrive/clothing_class/model_folder/'+str(cp_name)
                             )

# %% [markdown]
# ## Model Functions

# %% [markdown]
# I elected to proceed with showcasing the transfer learning modeling using VGG16 alone for this stage.
#
# The below function allows for the Dense layer units to be specified, as well as for an Adam learning rate to be specified. Generally a learning rate of .01 was used when modeling with VGG16 transfer learning during this stage of analysis.
#
# In addition to the layers inherent to the VGG architecture, additional Dense, Batch normalization, and dropout layers were addded. This particular architecture seemed to generate the best scores accross the various image sets.

# %%
def model_function(classes,alr):
  
    base_model = VGG16(include_top=False,
                     input_shape=(224, 224, 3),
                     weights='imagenet'
                     )
    for layer in base_model.layers:
        layer.trainable = False
    
    model = tf.keras.Sequential([
        
        base_model,
        
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.BatchNormalization(),
        
        tf.keras.layers.Dense(32,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Dense(256,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(256,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),

        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Dense(32,activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(rate=0.2),
        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(64,activation='relu'),

        tf.keras.layers.Dense(units=classes, activation='softmax')
    ])
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(learning_rate=alr),
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# To observe the impact of transfer learning, an additional function was set up with a similar structure to the above VGG model, without the transfer learning.

# %%
def seq_model_function(classes,alr):

  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu',
                 padding='same',input_shape=(224,224,3)))
  model.add(MaxPool2D(pool_size=(2, 2)))

  model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))

  model.add(Flatten())
  model.add(Dense(64, activation='relu'))

  model.add(Dense(units=classes, activation='softmax'))

  model.compile(loss='categorical_crossentropy',metrics="accuracy",optimizer=Adam(learning_rate=alr))

  return model

# %% [markdown]
# ## Plot Functions

# %% [markdown]
# A function was built to plot the accuracy and validation accuracy at each epoch. The plot is displayed and saved down to a seperate folder.

# %%
def plot_accuracy(history,title,ext):
  plt.figure(figsize=(20,10))
  plt.plot(history.history['accuracy'], label='Train')
  plt.plot(history.history['val_accuracy'], label='Test')
  plt.ylabel('Accuracy',fontsize=20)
  plt.xlabel('Epochs',fontsize=20)
  plt.legend(prop={'size': 20})
  plt.title(title,fontsize=20)
  plt.savefig('/content/drive/MyDrive/clothing_class/jpegs/'+str(ext)+'_acc.jpeg',format='jpeg',bbox_inches='tight');

# %% [markdown]
# A function was built to plot the confusion matrix for each model, using the model predictions and the ground truths for the test set. The matrix is displayed and saved down to a seperate folder.

# %%
def plot_confusion_matrix(checkpoint,test_data,title,ext):
  preds = load_model('/content/drive/MyDrive/clothing_class/model_folder/'+checkpoint).predict(test_data)
  top_pred = np.argmax(preds,axis=1)

  labels = (test_data.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  predictions = [labels[k] for k in top_pred]

  label_true = [labels[k] for k in test_data.classes]

  fig,ax = plt.subplots(figsize=(20,10))
  ConfusionMatrixDisplay.from_predictions(label_true,
                                        predictions,cmap='Blues',
                                        ax=ax,
                                        )
  ax.set_xlabel('Predicted Label',fontsize=15)
  ax.set_ylabel('True Label',fontsize=15)
  plt.title(title,fontsize=20)
  plt.show()
  fig.savefig('/content/drive/MyDrive/clothing_class/jpegs/'+str(ext)+'_cm.jpeg',format='jpeg',bbox_inches='tight');

# %% [markdown]
# ## Function for Calculating Balanced Accuracy

# %% [markdown]
# A function was created to calculate the balanced accuracy for a given model and dataset.

# %%
def calculate_balanced_acc(model,dataframe,image_file,y_col):
  
  test_data = tensor_data(test_gen,dataframe,image_file,
                   y_col,'validation')
  
  preds = load_model('/content/drive/MyDrive/clothing_class/model_folder/'+model).predict(test_data)
  top_pred = np.argmax(preds,axis=1)

  labels = (test_data.class_indices)
  labels = dict((v,k) for k,v in labels.items())
  predictions = [labels[k] for k in top_pred]

  label_true = [labels[k] for k in test_data.classes]

  return sklearn.metrics.balanced_accuracy_score(label_true,predictions)

# %% [markdown]
# ## Baselines

# %% [markdown]
# Reviewing the baseline values for these datasets to determine the accuracy level that must be surpassed to determine that a model performs better than merely choosing the majority class every time.

# %%
clothes_df['garment_label'].value_counts(normalize=True)
# Out:
# dress      0.139226
# sweater    0.136002
# coat       0.134484
# pants      0.129932
# tshirt     0.116654
# top        0.107360
# jacket     0.087253
# shorts     0.086495
# skirt      0.062595
# Name: garment_label, dtype: float64

# %% [markdown]
# The garment baseline for the dataset is ~14%.

# %%
clothes_df['pattern_label'].value_counts(normalize=True)
# Out:
# solid        0.567527
# horiz        0.161798
# polka        0.091426
# vertical     0.040971
# chevron      0.039264
# checkered    0.039264
# animal       0.036039
# paisley      0.023710
# Name: pattern_label, dtype: float64

# %% [markdown]
# The pattern baseline for the whole dataset is 56.7%.

# %%
resampled_df['pattern_label'].value_counts(normalize=True)
# Out:
# horiz        0.296386
# solid        0.207783
# polka        0.167477
# vertical     0.075052
# chevron      0.071925
# checkered    0.071925
# animal       0.066018
# paisley      0.043433
# Name: pattern_label, dtype: float64

# %% [markdown]
# The pattern baseline for the resampled dataset (which downsamples solid patterns) is ~30%. The resampled dataset will only be used for pattern modeling.

# %% [markdown]
# # Modeling

# %% [markdown]
# The below modeling aims to identify the augmentation/segmentation that generates the best accuracy when attempting to classify type of garment/garment pattern within an image.

# %% [markdown]
# It should be noted that the test sets are segmented as well (but not augmented). If a certain kind of segmentation especially lends itself to classifying type of garment or pattern, we would consider segmenting future 'new' images as they are received and prepared to be classified.

# %% [markdown]
# ## Transfer Learning Pattern Model - KMeans (K=5)

# %%
model_vp_kmeans = model_function(classes = 8,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_kmeans,
                  'pattern_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_kmeans,
                  'pattern_label','validation')

checkpoint_model_vp_kmeans = checkpoint('model_vp_kmeans')

history_vp_kmeans = model_vp_kmeans.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_kmeans,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vp_kmeans,'Patterns - K-means Segmentation, VGG16: Accuracy',
              'kmeans_pattern_transfer')

plot_confusion_matrix('model_vp_kmeans',test_data,
                      'Patterns - K-means Segmentation, VGG16: Confusion Matrix',
                      'kmeans_pattern_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 8 classes.
# Found 1054 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1350 - accuracy: 0.6655INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 72s 522ms/step - loss: 1.1350 - accuracy: 0.6655 - val_loss: 0.9108 - val_accuracy: 0.7258
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8930 - accuracy: 0.7357INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 522ms/step - loss: 0.8930 - accuracy: 0.7357 - val_loss: 0.7358 - val_accuracy: 0.7742
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8042 - accuracy: 0.7565INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 520ms/step - loss: 0.8042 - accuracy: 0.7565 - val_loss: 0.6407 - val_accuracy: 0.8178
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7486 - accuracy: 0.7715INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 70s 532ms/step - loss: 0.7486 - accuracy: 0.7715 - val_loss: 0.5605 - val_accuracy: 0.8302
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7164 - accuracy: 0.7862INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 526ms/step - loss: 0.7164 - accuracy: 0.7862 - val_loss: 0.4917 - val_accuracy: 0.8586
# Epoch 6/50
# 132/132 [==============================] - 64s 484ms/step - loss: 0.7023 - accuracy: 0.7945 - val_loss: 0.5719 - val_accuracy: 0.8368
# Epoch 7/50
# 132/132 [==============================] - 65s 489ms/step - loss: 0.6893 - accuracy: 0.7921 - val_loss: 0.5639 - val_accuracy: 0.8368
# Epoch 8/50
# 132/132 [==============================] - 64s 483ms/step - loss: 0.6651 - accuracy: 0.7971 - val_loss: 0.5330 - val_accuracy: 0.8444
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6474 - accuracy: 0.8061INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 519ms/step - loss: 0.6474 - accuracy: 0.8061 - val_loss: 0.5198 - val_accuracy: 0.8643
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.8132INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 525ms/step - loss: 0.6345 - accuracy: 0.8132 - val_loss: 0.4610 - val_accuracy: 0.8833
# Epoch 11/50
# 132/132 [==============================] - 63s 478ms/step - loss: 0.6292 - accuracy: 0.8158 - val_loss: 0.4761 - val_accuracy: 0.8719
# Epoch 12/50
# 132/132 [==============================] - 63s 477ms/step - loss: 0.6178 - accuracy: 0.8205 - val_loss: 0.4896 - val_accuracy: 0.8653
# Epoch 13/50
# 132/132 [==============================] - 63s 478ms/step - loss: 0.6048 - accuracy: 0.8265 - val_loss: 0.4856 - val_accuracy: 0.8681
# Epoch 14/50
# 132/132 [==============================] - 65s 489ms/step - loss: 0.5976 - accuracy: 0.8293 - val_loss: 0.4346 - val_accuracy: 0.8805
# Epoch 15/50
# 132/132 [==============================] - 63s 478ms/step - loss: 0.6074 - accuracy: 0.8276 - val_loss: 0.4493 - val_accuracy: 0.8833
# Epoch 16/50
# 132/132 [==============================] - 63s 476ms/step - loss: 0.5792 - accuracy: 0.8355 - val_loss: 0.4567 - val_accuracy: 0.8757
# Epoch 17/50
# 132/132 [==============================] - 63s 476ms/step - loss: 0.5870 - accuracy: 0.8338 - val_loss: 0.5520 - val_accuracy: 0.8615
# Epoch 18/50
# 132/132 [==============================] - 64s 484ms/step - loss: 0.5900 - accuracy: 0.8359 - val_loss: 0.4307 - val_accuracy: 0.8729
# Epoch 19/50
# 132/132 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.8447INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 69s 520ms/step - loss: 0.5581 - accuracy: 0.8447 - val_loss: 0.4237 - val_accuracy: 0.8861
# Epoch 20/50
# 132/132 [==============================] - 63s 478ms/step - loss: 0.5476 - accuracy: 0.8464 - val_loss: 0.4474 - val_accuracy: 0.8691
# Epoch 21/50
# 132/132 [==============================] - 64s 483ms/step - loss: 0.5539 - accuracy: 0.8423 - val_loss: 0.4400 - val_accuracy: 0.8833
# Epoch 22/50
# 132/132 [==============================] - 65s 491ms/step - loss: 0.5400 - accuracy: 0.8473 - val_loss: 0.4133 - val_accuracy: 0.8852
# Epoch 23/50
# 132/132 [==============================] - 70s 529ms/step - loss: 0.5446 - accuracy: 0.8447 - val_loss: 0.3997 - val_accuracy: 0.8861
# Epoch 24/50
# 132/132 [==============================] - 65s 491ms/step - loss: 0.5416 - accuracy: 0.8438 - val_loss: 0.4132 - val_accuracy: 0.8795
# Epoch 25/50
# 132/132 [==============================] - 63s 476ms/step - loss: 0.5415 - accuracy: 0.8502 - val_loss: 0.3898 - val_accuracy: 0.8843
# Epoch 26/50
# 132/132 [==============================] - 63s 476ms/step - loss: 0.5514 - accuracy: 0.8471 - val_loss: 0.4009 - val_accuracy: 0.8861
# Epoch 27/50
# 132/132 [==============================] - 63s 477ms/step - loss: 0.5559 - accuracy: 0.8435 - val_loss: 0.4110 - val_accuracy: 0.8824
# Epoch 28/50
# 132/132 [==============================] - 65s 491ms/step - loss: 0.5240 - accuracy: 0.8466 - val_loss: 0.4646 - val_accuracy: 0.8643
# Epoch 29/50
# 132/132 [==============================] - 65s 489ms/step - loss: 0.5380 - accuracy: 0.8487 - val_loss: 0.4190 - val_accuracy: 0.8776
# Epoch 30/50
# 132/132 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.8521INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans/assets
# 132/132 [==============================] - 79s 601ms/step - loss: 0.5185 - accuracy: 0.8521 - val_loss: 0.4381 - val_accuracy: 0.8871

# %% [markdown]
# The transfer learning model using K-Means segmented images scored fairly strongly on the pattern dataset, achieving a validation accuracy of 88.71%.
#
# The areas of notable misclassification are horizontal, polkadot and paisley print being misclassified as solids.

# %%
calculate_balanced_acc('model_vp_kmeans',clothes_df,imseg_data_path_kmeans,'pattern_label')
# Out:
# Found 1054 non-validated image filenames belonging to 8 classes.
# 0.7517188125825591

# %% [markdown]
# Due to the dataset's imbalance, the balanced accuracy on the testing set fell to 75.17%.

# %% [markdown]
# ## Transfer Learning Model, K-Means (K=5) - Resampled Pattern Data

# %%
model_vp_kmeans_r = model_function(classes = 8,alr=.01)

train_data = tensor_data(aug_train_gen,resampled_df,imseg_data_path_kmeans,
                  'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,imseg_data_path_kmeans,
                  'pattern_label','validation')

checkpoint_model_vp_kmeans_r = checkpoint('model_vp_kmeans_r')

history_vp_kmeans_r = model_vp_kmeans_r.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_kmeans_r,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vp_kmeans_r,'Patterns, Resampled - K-means Segmentation, VGG16: Accuracy',
              'kmeans_pattern_transfer_r')

plot_confusion_matrix('model_vp_kmeans_r',test_data,
                      'Patterns, Resampled - K-means Segmentation, VGG16: Confusion Matrix',
                      'kmeans_pattern_transfer_r')
# Out:
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 1.5926 - accuracy: 0.4347INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 44s 588ms/step - loss: 1.5926 - accuracy: 0.4347 - val_loss: 1.3446 - val_accuracy: 0.4870
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 1.1967 - accuracy: 0.5997INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 40s 558ms/step - loss: 1.1967 - accuracy: 0.5997 - val_loss: 1.2318 - val_accuracy: 0.5600
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 1.0554 - accuracy: 0.6513INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 40s 553ms/step - loss: 1.0554 - accuracy: 0.6513 - val_loss: 0.8372 - val_accuracy: 0.7357
# Epoch 4/50
# 72/72 [==============================] - 35s 478ms/step - loss: 0.9665 - accuracy: 0.6952 - val_loss: 0.9837 - val_accuracy: 0.7165
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9279 - accuracy: 0.7230INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 39s 548ms/step - loss: 0.9279 - accuracy: 0.7230 - val_loss: 0.8235 - val_accuracy: 0.7461
# Epoch 6/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9227 - accuracy: 0.7117INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 40s 552ms/step - loss: 0.9227 - accuracy: 0.7117 - val_loss: 0.7513 - val_accuracy: 0.7617
# Epoch 7/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8690 - accuracy: 0.7317INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 41s 566ms/step - loss: 0.8690 - accuracy: 0.7317 - val_loss: 0.6698 - val_accuracy: 0.8052
# Epoch 8/50
# 72/72 [==============================] - 35s 481ms/step - loss: 0.8425 - accuracy: 0.7382 - val_loss: 0.6901 - val_accuracy: 0.7983
# Epoch 9/50
# 72/72 [==============================] - 34s 476ms/step - loss: 0.7976 - accuracy: 0.7551 - val_loss: 0.6552 - val_accuracy: 0.7983
# Epoch 10/50
# 72/72 [==============================] - 34s 477ms/step - loss: 0.7865 - accuracy: 0.7660 - val_loss: 0.6808 - val_accuracy: 0.7826
# Epoch 11/50
# 72/72 [==============================] - 35s 480ms/step - loss: 0.7873 - accuracy: 0.7590 - val_loss: 0.6874 - val_accuracy: 0.7930
# Epoch 12/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7613 - accuracy: 0.7673INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans_r/assets
# 72/72 [==============================] - 41s 564ms/step - loss: 0.7613 - accuracy: 0.7673 - val_loss: 0.6667 - val_accuracy: 0.8104
# Epoch 13/50
# 72/72 [==============================] - 35s 478ms/step - loss: 0.7546 - accuracy: 0.7742 - val_loss: 0.7007 - val_accuracy: 0.7930
# Epoch 14/50
# 72/72 [==============================] - 34s 475ms/step - loss: 0.7591 - accuracy: 0.7694 - val_loss: 0.9026 - val_accuracy: 0.7061

# %% [markdown]
# When reviewing the validation accuracy score of a model fed K-Means images on the dataset that drastically downsampled solids, accuracy fell relative to the less balanced dataset.
#
# A misclassification pattern similar to the K-means misclassifications for the complete dataset developed on the more imbalanced data.

# %%
calculate_balanced_acc('model_vp_kmeans_r',resampled_df,imseg_data_path_kmeans,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.7555127064462299

# %% [markdown]
# ## Transfer Learning Garment Model - KMeans (K =5)

# %%
model_vg_kmeans = model_function(classes = 9,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_kmeans,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_kmeans,
                  'garment_label','validation')

checkpoint_model_vg_kmeans = checkpoint('model_vg_kmeans')

history_vg_kmeans = model_vg_kmeans.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_kmeans,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vg_kmeans,'Garments - K-means Segmentation, VGG16: Accuracy',
              'kmeans_garment_transfer')

plot_confusion_matrix('model_vg_kmeans',test_data,
                      'Garments - K-means Segmentation, VGG16: Confusion Matrix',
                      'kmeans_garment_transfer')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 2.0031 - accuracy: 0.2655INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 1492s 11s/step - loss: 2.0031 - accuracy: 0.2655 - val_loss: 2.3942 - val_accuracy: 0.1879
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7513 - accuracy: 0.3687INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 474ms/step - loss: 1.7513 - accuracy: 0.3687 - val_loss: 1.7768 - val_accuracy: 0.3378
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6323 - accuracy: 0.4113INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 64s 489ms/step - loss: 1.6323 - accuracy: 0.4113 - val_loss: 1.4622 - val_accuracy: 0.4639
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5469 - accuracy: 0.4386INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 475ms/step - loss: 1.5469 - accuracy: 0.4386 - val_loss: 1.2710 - val_accuracy: 0.5342
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5014 - accuracy: 0.4666INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 475ms/step - loss: 1.5014 - accuracy: 0.4666 - val_loss: 1.1960 - val_accuracy: 0.5835
# Epoch 6/50
# 132/132 [==============================] - 58s 436ms/step - loss: 1.4687 - accuracy: 0.4808 - val_loss: 1.2246 - val_accuracy: 0.5702
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4235 - accuracy: 0.4938INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 64s 482ms/step - loss: 1.4235 - accuracy: 0.4938 - val_loss: 1.1164 - val_accuracy: 0.6025
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3918 - accuracy: 0.5138INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 478ms/step - loss: 1.3918 - accuracy: 0.5138 - val_loss: 1.0999 - val_accuracy: 0.6044
# Epoch 9/50
# 132/132 [==============================] - 62s 469ms/step - loss: 1.3725 - accuracy: 0.5159 - val_loss: 1.1532 - val_accuracy: 0.5835
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3566 - accuracy: 0.5256INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 67s 509ms/step - loss: 1.3566 - accuracy: 0.5256 - val_loss: 1.0941 - val_accuracy: 0.6167
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3585 - accuracy: 0.5159INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 64s 486ms/step - loss: 1.3585 - accuracy: 0.5159 - val_loss: 1.0003 - val_accuracy: 0.6395
# Epoch 12/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3366 - accuracy: 0.5391INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 474ms/step - loss: 1.3366 - accuracy: 0.5391 - val_loss: 1.0275 - val_accuracy: 0.6490
# Epoch 13/50
# 132/132 [==============================] - 59s 448ms/step - loss: 1.3111 - accuracy: 0.5448 - val_loss: 1.0752 - val_accuracy: 0.6101
# Epoch 14/50
# 132/132 [==============================] - 57s 434ms/step - loss: 1.3142 - accuracy: 0.5455 - val_loss: 1.0693 - val_accuracy: 0.6214
# Epoch 15/50
# 132/132 [==============================] - 57s 434ms/step - loss: 1.2965 - accuracy: 0.5548 - val_loss: 1.0168 - val_accuracy: 0.6347
# Epoch 16/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2688 - accuracy: 0.5704INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans/assets
# 132/132 [==============================] - 63s 480ms/step - loss: 1.2688 - accuracy: 0.5704 - val_loss: 1.0012 - val_accuracy: 0.6537

# %%
calculate_balanced_acc('model_vg_kmeans',clothes_df,imseg_data_path_kmeans,'garment_label')
# Out:
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.6255094873903241

# %% [markdown]
# The type of garment is harder to identify in the images than pattern.
#
# The transfer learning model, when fed images segmented via 5 K-Means clusters, classified garments with a peak validation accuracy of 65.37%, and a balanced accuracy score of 62.5%.
#
# Notable misclassifications are what might be expected, given the similarity in the nature of the items:
# * Coats and jackets
# * Tops/T-Shirts/Sweaters
# * Dresses and Skirts

# %% [markdown]
# ## Transfer Learning Model, K-Means (K=3) - Resampled Pattern Data

# %%
model_vp_kmeans3_r = model_function(classes = 8,alr=.01)

train_data = tensor_data(aug_train_gen,resampled_df,imseg_data_path_kmeans3,
                  'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,imseg_data_path_kmeans3,
                  'pattern_label','validation')

checkpoint_model_vp_kmeans3_r = checkpoint('model_vp_kmeans3_r')

history_vp_kmeans3_r = model_vp_kmeans3_r.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_kmeans3_r,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vp_kmeans3_r,'Patterns, Resampled - K-means (K=3) Segmentation, VGG16: Accuracy',
              'kmeans3_pattern_transfer_r')

plot_confusion_matrix('model_vp_kmeans3_r',test_data,
                      'Patterns, Resampled - K-means (K=3) Segmentation, VGG16: Confusion Matrix',
                      'kmeans3_pattern_transfer_r')
# Out:
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.4355INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 49s 650ms/step - loss: 1.6244 - accuracy: 0.4355 - val_loss: 1.3990 - val_accuracy: 0.5426
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 1.2938 - accuracy: 0.5662INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 57s 790ms/step - loss: 1.2938 - accuracy: 0.5662 - val_loss: 1.2196 - val_accuracy: 0.6174
# Epoch 3/50
# 72/72 [==============================] - 38s 534ms/step - loss: 1.1506 - accuracy: 0.6092 - val_loss: 1.3715 - val_accuracy: 0.5791
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 1.0917 - accuracy: 0.6235INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 41s 567ms/step - loss: 1.0917 - accuracy: 0.6235 - val_loss: 1.0878 - val_accuracy: 0.6626
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 1.0480 - accuracy: 0.6535INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 37s 518ms/step - loss: 1.0480 - accuracy: 0.6535 - val_loss: 0.9356 - val_accuracy: 0.6678
# Epoch 6/50
# 72/72 [==============================] - ETA: 0s - loss: 1.0369 - accuracy: 0.6522INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 39s 538ms/step - loss: 1.0369 - accuracy: 0.6522 - val_loss: 0.9472 - val_accuracy: 0.7270
# Epoch 7/50
# 72/72 [==============================] - 34s 472ms/step - loss: 0.9947 - accuracy: 0.6765 - val_loss: 0.8783 - val_accuracy: 0.7078
# Epoch 8/50
# 72/72 [==============================] - 32s 437ms/step - loss: 0.9843 - accuracy: 0.6539 - val_loss: 0.8868 - val_accuracy: 0.7096
# Epoch 9/50
# 72/72 [==============================] - 32s 437ms/step - loss: 0.9930 - accuracy: 0.6761 - val_loss: 0.9015 - val_accuracy: 0.7200
# Epoch 10/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9376 - accuracy: 0.6809INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 37s 508ms/step - loss: 0.9376 - accuracy: 0.6809 - val_loss: 0.7995 - val_accuracy: 0.7461
# Epoch 11/50
# 72/72 [==============================] - 32s 439ms/step - loss: 0.9345 - accuracy: 0.6939 - val_loss: 0.8457 - val_accuracy: 0.7165
# Epoch 12/50
# 72/72 [==============================] - 31s 436ms/step - loss: 0.9205 - accuracy: 0.6930 - val_loss: 0.8248 - val_accuracy: 0.7304
# Epoch 13/50
# 72/72 [==============================] - 31s 436ms/step - loss: 0.8697 - accuracy: 0.7156 - val_loss: 0.7839 - val_accuracy: 0.7443
# Epoch 14/50
# 72/72 [==============================] - 31s 437ms/step - loss: 0.8855 - accuracy: 0.7052 - val_loss: 0.8243 - val_accuracy: 0.7304
# Epoch 15/50
# 72/72 [==============================] - 32s 444ms/step - loss: 0.8949 - accuracy: 0.7060 - val_loss: 0.8687 - val_accuracy: 0.7287
# Epoch 16/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9190 - accuracy: 0.7047INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 38s 522ms/step - loss: 0.9190 - accuracy: 0.7047 - val_loss: 0.7738 - val_accuracy: 0.7583
# Epoch 17/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8568 - accuracy: 0.7321INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 36s 504ms/step - loss: 0.8568 - accuracy: 0.7321 - val_loss: 0.7736 - val_accuracy: 0.7617
# Epoch 18/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8292 - accuracy: 0.7503INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 37s 511ms/step - loss: 0.8292 - accuracy: 0.7503 - val_loss: 0.7482 - val_accuracy: 0.7722
# Epoch 19/50
# 72/72 [==============================] - 32s 439ms/step - loss: 0.8396 - accuracy: 0.7403 - val_loss: 0.7959 - val_accuracy: 0.7652
# Epoch 20/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8266 - accuracy: 0.7460INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_kmeans3_r/assets
# 72/72 [==============================] - 36s 507ms/step - loss: 0.8266 - accuracy: 0.7460 - val_loss: 0.7449 - val_accuracy: 0.7843
# Epoch 21/50
# 72/72 [==============================] - 32s 439ms/step - loss: 0.8370 - accuracy: 0.7377 - val_loss: 0.7272 - val_accuracy: 0.7826
# Epoch 22/50
# 72/72 [==============================] - 31s 435ms/step - loss: 0.8046 - accuracy: 0.7564 - val_loss: 0.7787 - val_accuracy: 0.7652
# Epoch 23/50
# 72/72 [==============================] - 31s 434ms/step - loss: 0.8010 - accuracy: 0.7603 - val_loss: 0.8938 - val_accuracy: 0.7357
# Epoch 24/50
# 72/72 [==============================] - 32s 447ms/step - loss: 0.8012 - accuracy: 0.7551 - val_loss: 0.8582 - val_accuracy: 0.7461
# Epoch 25/50
# 72/72 [==============================] - 33s 451ms/step - loss: 0.8114 - accuracy: 0.7495 - val_loss: 0.7422 - val_accuracy: 0.7826
# Epoch 26/50
# 72/72 [==============================] - 32s 437ms/step - loss: 0.7813 - accuracy: 0.7581 - val_loss: 0.8254 - val_accuracy: 0.7617

# %% [markdown]
# To see if reducing the number of clusters K-Means uses to segment the image might affect the accuracy, the same model was run on the images segmented using only 3 clusters.
#
# As might be expected when the image is segmented using fewer shading clusters, the model more often misclassifies striped (horizontal and chevron) and checkered patterns as solids because it is less proficient at distinguishing between the lines of stripe.

# %%
calculate_balanced_acc('model_vp_kmeans3_r',resampled_df,imseg_data_path_kmeans3,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.7396965866551435

# %% [markdown]
# Ultimately, using fewer clusters in the K-Means segmentation negatively affected the balanced accuracy score, relative to the models fed images processed with 5 clusters.

# %% [markdown]
# ## Transfer Learning - Garment Model, K-Means (K=3) Segmentation

# %%
model_vg_kmeans3 = model_function(classes = 9,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_kmeans3,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_kmeans3,
                  'garment_label','validation')

checkpoint_model_vg_kmeans3 = checkpoint('model_vg_kmeans3')

history_vg_kmeans3 = model_vg_kmeans3.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_kmeans3,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vg_kmeans3,'Garments, K-means (K=3) Segmentation, VGG16: Accuracy',
              'kmeans3_garment_transfer')

plot_confusion_matrix('model_vg_kmeans3',test_data,
                      'Garments, K-means (K=3) Segmentation, VGG16: Confusion Matrix',
                      'kmeans3_garment_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 2.0083 - accuracy: 0.2541INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 67s 490ms/step - loss: 2.0083 - accuracy: 0.2541 - val_loss: 2.0253 - val_accuracy: 0.2875
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7864 - accuracy: 0.3483INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 62s 473ms/step - loss: 1.7864 - accuracy: 0.3483 - val_loss: 1.8542 - val_accuracy: 0.3112
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6990 - accuracy: 0.3762INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 62s 470ms/step - loss: 1.6990 - accuracy: 0.3762 - val_loss: 1.4524 - val_accuracy: 0.4146
# Epoch 4/50
# 132/132 [==============================] - 57s 434ms/step - loss: 1.6350 - accuracy: 0.4016 - val_loss: 1.6369 - val_accuracy: 0.4137
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6051 - accuracy: 0.4263INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 63s 475ms/step - loss: 1.6051 - accuracy: 0.4263 - val_loss: 1.3642 - val_accuracy: 0.4782
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5575 - accuracy: 0.4414INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 64s 484ms/step - loss: 1.5575 - accuracy: 0.4414 - val_loss: 1.3355 - val_accuracy: 0.5285
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5304 - accuracy: 0.4528INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 63s 475ms/step - loss: 1.5304 - accuracy: 0.4528 - val_loss: 1.2400 - val_accuracy: 0.5693
# Epoch 8/50
# 132/132 [==============================] - 57s 434ms/step - loss: 1.4821 - accuracy: 0.4765 - val_loss: 1.2235 - val_accuracy: 0.5455
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5020 - accuracy: 0.4602INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 62s 468ms/step - loss: 1.5020 - accuracy: 0.4602 - val_loss: 1.1502 - val_accuracy: 0.5863
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4560 - accuracy: 0.4822INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 64s 484ms/step - loss: 1.4560 - accuracy: 0.4822 - val_loss: 1.1210 - val_accuracy: 0.5977
# Epoch 11/50
# 132/132 [==============================] - 58s 437ms/step - loss: 1.4319 - accuracy: 0.5002 - val_loss: 1.1649 - val_accuracy: 0.5835
# Epoch 12/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4303 - accuracy: 0.4981INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 62s 471ms/step - loss: 1.4303 - accuracy: 0.4981 - val_loss: 1.1299 - val_accuracy: 0.6053
# Epoch 13/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4205 - accuracy: 0.5000INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 62s 473ms/step - loss: 1.4205 - accuracy: 0.5000 - val_loss: 1.1110 - val_accuracy: 0.6063
# Epoch 14/50
# 132/132 [==============================] - 57s 435ms/step - loss: 1.4309 - accuracy: 0.4962 - val_loss: 1.0964 - val_accuracy: 0.5920
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3767 - accuracy: 0.5254INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_kmeans3/assets
# 132/132 [==============================] - 63s 478ms/step - loss: 1.3767 - accuracy: 0.5254 - val_loss: 1.1469 - val_accuracy: 0.6110
# Epoch 16/50
# 132/132 [==============================] - 58s 440ms/step - loss: 1.3953 - accuracy: 0.5071 - val_loss: 1.2003 - val_accuracy: 0.5987
# Epoch 17/50
# 132/132 [==============================] - 57s 433ms/step - loss: 1.3953 - accuracy: 0.5152 - val_loss: 1.2828 - val_accuracy: 0.5560
# Epoch 18/50
# 132/132 [==============================] - 57s 433ms/step - loss: 1.3806 - accuracy: 0.5306 - val_loss: 1.1252 - val_accuracy: 0.6110
# Epoch 19/50
# 132/132 [==============================] - 57s 434ms/step - loss: 1.3526 - accuracy: 0.5303 - val_loss: 1.1530 - val_accuracy: 0.6034

# %% [markdown]
# When using 3 clusters to segment the image via K-Means, the model classifying garments performed worse than the model fed data segmented with five clusters, with similar misclassifications.

# %% [markdown]
# ## Sequential Pattern Model - Contour

# %%
model_sp_contour = seq_model_function(classes = 8,alr=.001)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_contour,
                  'pattern_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_contour,
                  'pattern_label','validation')

checkpoint_model_sp_contour = checkpoint('model_sp_contour')

history_sp_contour = model_sp_contour.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_sp_contour,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_sp_contour,'Patterns - Contour Segmentation, No Transfer Learning: Accuracy',
              'contour_pattern_cnn')

plot_confusion_matrix('model_sp_contour',test_data,
                      'Patterns - Contour Segmentation, No Transfer Learning: Confusion Matrix',
                      'contour_pattern_cnn')
# Out:
# Found 4218 non-validated image filenames belonging to 8 classes.
# Found 1054 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4665 - accuracy: 0.5576INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 78s 579ms/step - loss: 1.4665 - accuracy: 0.5576 - val_loss: 1.4386 - val_accuracy: 0.5636
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2582 - accuracy: 0.6238INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 62s 471ms/step - loss: 1.2582 - accuracy: 0.6238 - val_loss: 1.1386 - val_accuracy: 0.6755
# Epoch 3/50
# 132/132 [==============================] - 56s 427ms/step - loss: 1.2015 - accuracy: 0.6437 - val_loss: 1.1392 - val_accuracy: 0.6689
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1749 - accuracy: 0.6522INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 1.1749 - accuracy: 0.6522 - val_loss: 1.1357 - val_accuracy: 0.6822
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1505 - accuracy: 0.6543INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.1505 - accuracy: 0.6543 - val_loss: 1.0747 - val_accuracy: 0.7002
# Epoch 6/50
# 132/132 [==============================] - 61s 466ms/step - loss: 1.1376 - accuracy: 0.6629 - val_loss: 1.0992 - val_accuracy: 0.6822
# Epoch 7/50
# 132/132 [==============================] - 59s 444ms/step - loss: 1.1404 - accuracy: 0.6603 - val_loss: 1.0860 - val_accuracy: 0.6992
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0933 - accuracy: 0.6735INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 62s 474ms/step - loss: 1.0933 - accuracy: 0.6735 - val_loss: 1.0272 - val_accuracy: 0.7125
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0914 - accuracy: 0.6766INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 61s 461ms/step - loss: 1.0914 - accuracy: 0.6766 - val_loss: 0.9796 - val_accuracy: 0.7182
# Epoch 10/50
# 132/132 [==============================] - 58s 441ms/step - loss: 1.0571 - accuracy: 0.6892 - val_loss: 0.9494 - val_accuracy: 0.7135
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0363 - accuracy: 0.7022INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 59s 447ms/step - loss: 1.0363 - accuracy: 0.7022 - val_loss: 0.9432 - val_accuracy: 0.7220
# Epoch 12/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0070 - accuracy: 0.7022INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.0070 - accuracy: 0.7022 - val_loss: 0.9193 - val_accuracy: 0.7372
# Epoch 13/50
# 132/132 [==============================] - 58s 439ms/step - loss: 1.0026 - accuracy: 0.7037 - val_loss: 0.9244 - val_accuracy: 0.7277
# Epoch 14/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.9964 - accuracy: 0.7105 - val_loss: 1.0061 - val_accuracy: 0.6983
# Epoch 15/50
# 132/132 [==============================] - 56s 426ms/step - loss: 1.0023 - accuracy: 0.7048 - val_loss: 0.9199 - val_accuracy: 0.7343
# Epoch 16/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9711 - accuracy: 0.7098INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 0.9711 - accuracy: 0.7098 - val_loss: 0.8852 - val_accuracy: 0.7381
# Epoch 17/50
# 132/132 [==============================] - 58s 438ms/step - loss: 0.9527 - accuracy: 0.7112 - val_loss: 0.8724 - val_accuracy: 0.7353
# Epoch 18/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9537 - accuracy: 0.7141INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 437ms/step - loss: 0.9537 - accuracy: 0.7141 - val_loss: 0.8895 - val_accuracy: 0.7410
# Epoch 19/50
# 132/132 [==============================] - 56s 425ms/step - loss: 0.9425 - accuracy: 0.7193 - val_loss: 0.8637 - val_accuracy: 0.7362
# Epoch 20/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9325 - accuracy: 0.7191INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 59s 445ms/step - loss: 0.9325 - accuracy: 0.7191 - val_loss: 0.8558 - val_accuracy: 0.7419
# Epoch 21/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.7281INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_contour/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 0.9217 - accuracy: 0.7281 - val_loss: 0.8089 - val_accuracy: 0.7732
# Epoch 22/50
# 132/132 [==============================] - 57s 433ms/step - loss: 0.9138 - accuracy: 0.7366 - val_loss: 0.8227 - val_accuracy: 0.7647
# Epoch 23/50
# 132/132 [==============================] - 56s 425ms/step - loss: 0.9058 - accuracy: 0.7368 - val_loss: 0.8100 - val_accuracy: 0.7647
# Epoch 24/50
# 132/132 [==============================] - 57s 434ms/step - loss: 0.8720 - accuracy: 0.7451 - val_loss: 0.8392 - val_accuracy: 0.7609
# Epoch 25/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.8925 - accuracy: 0.7416 - val_loss: 0.8184 - val_accuracy: 0.7694
# Epoch 26/50
# 132/132 [==============================] - 56s 426ms/step - loss: 0.8852 - accuracy: 0.7451 - val_loss: 0.8565 - val_accuracy: 0.7476

# %% [markdown]
# The models that did not utilize transfer learning performed better for the contour segmented images than the models that used transfer learning. With its highest validation accuracy level at ~77%, the contour model performs considerably worse than K-Means model.
#
# Notable misclassifications again include paisley, polka and horizontal stripes but animal print, checkered and chevron striped misclassifications also become more common than in the K-Means model.

# %% [markdown]
# ## Transfer Learning Garment Model - Contour

# %%
model_vg_contour = model_function(classes = 9,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_contour,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_contour,
                  'garment_label','validation')

checkpoint_model_vg_contour = checkpoint('model_vg_contour')

history_vg_contour = model_vg_contour.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_contour,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vg_contour,'Garments- Contour Segmentation, Transfer Learning: Accuracy',
              'contour_garment_transfer')

plot_confusion_matrix('model_vg_contour',test_data,
                      'Garment - Contour Segmentation, Transfer Learning: Confusion Matrix',
                      'contour_garment_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 2.1031 - accuracy: 0.2051INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 1202s 9s/step - loss: 2.1031 - accuracy: 0.2051 - val_loss: 2.1545 - val_accuracy: 0.1641
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.9711 - accuracy: 0.2788INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 66s 499ms/step - loss: 1.9711 - accuracy: 0.2788 - val_loss: 1.9284 - val_accuracy: 0.3292
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.8927 - accuracy: 0.3151INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 64s 488ms/step - loss: 1.8927 - accuracy: 0.3151 - val_loss: 1.7812 - val_accuracy: 0.3321
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 1.8316 - accuracy: 0.3490INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 65s 490ms/step - loss: 1.8316 - accuracy: 0.3490 - val_loss: 1.8081 - val_accuracy: 0.3558
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7991 - accuracy: 0.3592INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 66s 498ms/step - loss: 1.7991 - accuracy: 0.3592 - val_loss: 1.8818 - val_accuracy: 0.3672
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7515 - accuracy: 0.3713INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 64s 488ms/step - loss: 1.7515 - accuracy: 0.3713 - val_loss: 1.5779 - val_accuracy: 0.4630
# Epoch 7/50
# 132/132 [==============================] - 60s 453ms/step - loss: 1.7312 - accuracy: 0.3753 - val_loss: 1.6981 - val_accuracy: 0.4137
# Epoch 8/50
# 132/132 [==============================] - 60s 455ms/step - loss: 1.7023 - accuracy: 0.3921 - val_loss: 1.6030 - val_accuracy: 0.4364
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6912 - accuracy: 0.3898INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 64s 483ms/step - loss: 1.6912 - accuracy: 0.3898 - val_loss: 1.4597 - val_accuracy: 0.4668
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6761 - accuracy: 0.3954INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 66s 502ms/step - loss: 1.6761 - accuracy: 0.3954 - val_loss: 1.4444 - val_accuracy: 0.5114
# Epoch 11/50
# 132/132 [==============================] - 63s 474ms/step - loss: 1.6312 - accuracy: 0.4052 - val_loss: 1.5511 - val_accuracy: 0.4269
# Epoch 12/50
# 132/132 [==============================] - 60s 452ms/step - loss: 1.6293 - accuracy: 0.4120 - val_loss: 1.4274 - val_accuracy: 0.4715
# Epoch 13/50
# 132/132 [==============================] - 59s 444ms/step - loss: 1.6237 - accuracy: 0.4175 - val_loss: 1.4874 - val_accuracy: 0.4725
# Epoch 14/50
# 132/132 [==============================] - 60s 453ms/step - loss: 1.6069 - accuracy: 0.4294 - val_loss: 1.4770 - val_accuracy: 0.4696
# Epoch 15/50
# 132/132 [==============================] - 58s 443ms/step - loss: 1.6071 - accuracy: 0.4241 - val_loss: 1.4987 - val_accuracy: 0.4820
# Epoch 16/50
# 132/132 [==============================] - 58s 442ms/step - loss: 1.5971 - accuracy: 0.4346 - val_loss: 1.5923 - val_accuracy: 0.4383
# Epoch 17/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6000 - accuracy: 0.4239INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 65s 490ms/step - loss: 1.6000 - accuracy: 0.4239 - val_loss: 1.3585 - val_accuracy: 0.5171
# Epoch 18/50
# 132/132 [==============================] - 60s 455ms/step - loss: 1.5988 - accuracy: 0.4267 - val_loss: 1.4451 - val_accuracy: 0.4839
# Epoch 19/50
# 132/132 [==============================] - 58s 443ms/step - loss: 1.5960 - accuracy: 0.4329 - val_loss: 1.4493 - val_accuracy: 0.5085
# Epoch 20/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5902 - accuracy: 0.4412INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_contour/assets
# 132/132 [==============================] - 63s 479ms/step - loss: 1.5902 - accuracy: 0.4412 - val_loss: 1.3403 - val_accuracy: 0.5209
# Epoch 21/50
# 132/132 [==============================] - 60s 452ms/step - loss: 1.5825 - accuracy: 0.4317 - val_loss: 1.3930 - val_accuracy: 0.4972
# Epoch 22/50
# 132/132 [==============================] - 59s 447ms/step - loss: 1.5786 - accuracy: 0.4405 - val_loss: 1.3806 - val_accuracy: 0.5085
# Epoch 23/50
# 132/132 [==============================] - 58s 441ms/step - loss: 1.5723 - accuracy: 0.4412 - val_loss: 1.4543 - val_accuracy: 0.5028
# Epoch 24/50
# 132/132 [==============================] - 60s 453ms/step - loss: 1.5556 - accuracy: 0.4493 - val_loss: 1.4776 - val_accuracy: 0.4611
# Epoch 25/50
# 132/132 [==============================] - 58s 442ms/step - loss: 1.5513 - accuracy: 0.4379 - val_loss: 1.6584 - val_accuracy: 0.4820

# %% [markdown]
# The model fed the contour segmented images, when using transfer learning, performs considerably worse than the K-Means trained model, with its best validation accuracy of 52%. Areas of frequent misclassification, in addition to those that are frequent in the K-Means model are:
#
# * Shorts/pants
# * Sweater/jacket

# %% [markdown]
# ## Sequential Pattern Model - Thresholding

# %%
model_sp_thresh = seq_model_function(classes = 8,alr=.001)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_thresh,
                  'pattern_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_thresh,
                  'pattern_label','validation')

checkpoint_model_sp_thresh = checkpoint('model_sp_thresh')

history_sp_thresh = model_sp_thresh.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_sp_thresh,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_sp_thresh,'Patterns - Thresholding Segmentation, No Transfer Learning: Accuracy',
              'thresh_pattern_cnn')

plot_confusion_matrix('model_sp_thresh',test_data,
                      'Patterns - Thresholding Segmentation, No Transfer Learning: Confusion Matrix',
                      'thresh_pattern_cnn')
# Out:
# Found 4218 non-validated image filenames belonging to 8 classes.
# Found 1054 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4452 - accuracy: 0.5645INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 1133s 9s/step - loss: 1.4452 - accuracy: 0.5645 - val_loss: 1.3943 - val_accuracy: 0.5664
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2302 - accuracy: 0.6107INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.2302 - accuracy: 0.6107 - val_loss: 1.1649 - val_accuracy: 0.6537
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1027 - accuracy: 0.6536INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 59s 448ms/step - loss: 1.1027 - accuracy: 0.6536 - val_loss: 1.1183 - val_accuracy: 0.6546
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0651 - accuracy: 0.6619INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 442ms/step - loss: 1.0651 - accuracy: 0.6619 - val_loss: 0.9328 - val_accuracy: 0.7106
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0150 - accuracy: 0.6757INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 442ms/step - loss: 1.0150 - accuracy: 0.6757 - val_loss: 0.8877 - val_accuracy: 0.7343
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9857 - accuracy: 0.6989INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 60s 456ms/step - loss: 0.9857 - accuracy: 0.6989 - val_loss: 0.7859 - val_accuracy: 0.7533
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 0.9148 - accuracy: 0.7233INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 442ms/step - loss: 0.9148 - accuracy: 0.7233 - val_loss: 0.7395 - val_accuracy: 0.7903
# Epoch 8/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.8657 - accuracy: 0.7413 - val_loss: 0.7326 - val_accuracy: 0.7903
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8474 - accuracy: 0.7494INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 59s 446ms/step - loss: 0.8474 - accuracy: 0.7494 - val_loss: 0.6768 - val_accuracy: 0.7951
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8029 - accuracy: 0.7608INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 442ms/step - loss: 0.8029 - accuracy: 0.7608 - val_loss: 0.7137 - val_accuracy: 0.8008
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7862 - accuracy: 0.7634INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 59s 445ms/step - loss: 0.7862 - accuracy: 0.7634 - val_loss: 0.6435 - val_accuracy: 0.8027
# Epoch 12/50
# 132/132 [==============================] - 56s 428ms/step - loss: 0.7713 - accuracy: 0.7724 - val_loss: 0.7055 - val_accuracy: 0.7922
# Epoch 13/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7424 - accuracy: 0.7734INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 59s 447ms/step - loss: 0.7424 - accuracy: 0.7734 - val_loss: 0.6310 - val_accuracy: 0.8131
# Epoch 14/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7776INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 440ms/step - loss: 0.7365 - accuracy: 0.7776 - val_loss: 0.5768 - val_accuracy: 0.8197
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7174 - accuracy: 0.7850INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 438ms/step - loss: 0.7174 - accuracy: 0.7850 - val_loss: 0.6028 - val_accuracy: 0.8273
# Epoch 16/50
# 132/132 [==============================] - 58s 437ms/step - loss: 0.6951 - accuracy: 0.7961 - val_loss: 0.5706 - val_accuracy: 0.8207
# Epoch 17/50
# 132/132 [==============================] - 57s 429ms/step - loss: 0.7220 - accuracy: 0.7831 - val_loss: 0.7102 - val_accuracy: 0.7884
# Epoch 18/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.7947INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 438ms/step - loss: 0.6885 - accuracy: 0.7947 - val_loss: 0.5423 - val_accuracy: 0.8454
# Epoch 19/50
# 132/132 [==============================] - 58s 437ms/step - loss: 0.6897 - accuracy: 0.7940 - val_loss: 0.6433 - val_accuracy: 0.8065
# Epoch 20/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.6747 - accuracy: 0.7963 - val_loss: 0.5493 - val_accuracy: 0.8435
# Epoch 21/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.6662 - accuracy: 0.8049 - val_loss: 0.5344 - val_accuracy: 0.8378
# Epoch 22/50
# 132/132 [==============================] - 58s 439ms/step - loss: 0.6418 - accuracy: 0.8096 - val_loss: 0.5379 - val_accuracy: 0.8444
# Epoch 23/50
# 132/132 [==============================] - 56s 425ms/step - loss: 0.6324 - accuracy: 0.8065 - val_loss: 0.5386 - val_accuracy: 0.8435
# Epoch 24/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6312 - accuracy: 0.8132INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sp_thresh/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 0.6312 - accuracy: 0.8132 - val_loss: 0.5229 - val_accuracy: 0.8539
# Epoch 25/50
# 132/132 [==============================] - 56s 427ms/step - loss: 0.6064 - accuracy: 0.8217 - val_loss: 0.5483 - val_accuracy: 0.8330
# Epoch 26/50
# 132/132 [==============================] - 58s 437ms/step - loss: 0.6192 - accuracy: 0.8174 - val_loss: 0.5922 - val_accuracy: 0.8321
# Epoch 27/50
# 132/132 [==============================] - 57s 432ms/step - loss: 0.5997 - accuracy: 0.8267 - val_loss: 0.6495 - val_accuracy: 0.8036
# Epoch 28/50
# 132/132 [==============================] - 56s 425ms/step - loss: 0.5879 - accuracy: 0.8284 - val_loss: 0.6106 - val_accuracy: 0.8235
# Epoch 29/50
# 132/132 [==============================] - 58s 436ms/step - loss: 0.5860 - accuracy: 0.8241 - val_loss: 0.5410 - val_accuracy: 0.8472

# %% [markdown]
# For thresholding segmented images, the models that did not use transfer learning again performed better. At ~85%, the highest validation accuracy for the thresholding model is higher than contour, but lower than K-Means.
#
# Unlike the model that was fed contoured images, vertical stripes and animal prints were not notable areas of mislcassifications. The thresholding image model does misclassify paisley as checkered and polka, and misclassifies chevron and checkered at a similar rate to the contour model.

# %% [markdown]
# ## Sequential Garment Model - Thresholding

# %%
model_sg_thresh = seq_model_function(classes = 9,alr=.001)

train_data = tensor_data(aug_train_gen,clothes_df,imseg_data_path_thresh,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,imseg_data_path_thresh,
                  'garment_label','validation')

checkpoint_model_sg_thresh = checkpoint('model_sg_thresh')

history_sg_thresh = model_sg_thresh.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_sg_thresh,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_sg_thresh,'Garment - Thresholding Segmentation, No Transfer Learning: Accuracy',
              'thresh_garment_cnn')

plot_confusion_matrix('model_sg_thresh',test_data,
                      'Garments - Thresholding Segmentation, No Transfer Learning: Confusion Matrix',
                      'thresh_garment_cnn')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 2.1682 - accuracy: 0.1482INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 1213s 9s/step - loss: 2.1682 - accuracy: 0.1482 - val_loss: 2.1443 - val_accuracy: 0.1973
# Epoch 2/50
# 132/132 [==============================] - 57s 436ms/step - loss: 2.1394 - accuracy: 0.1726 - val_loss: 2.1030 - val_accuracy: 0.1793
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 2.0922 - accuracy: 0.2091INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 437ms/step - loss: 2.0922 - accuracy: 0.2091 - val_loss: 2.0113 - val_accuracy: 0.2647
# Epoch 4/50
# 132/132 [==============================] - 56s 425ms/step - loss: 2.0555 - accuracy: 0.2229 - val_loss: 2.0112 - val_accuracy: 0.2372
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 2.0110 - accuracy: 0.2544INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 450ms/step - loss: 2.0110 - accuracy: 0.2544 - val_loss: 1.9811 - val_accuracy: 0.2799
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 1.9556 - accuracy: 0.2741INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 442ms/step - loss: 1.9556 - accuracy: 0.2741 - val_loss: 1.7886 - val_accuracy: 0.3501
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 1.9172 - accuracy: 0.2835INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 438ms/step - loss: 1.9172 - accuracy: 0.2835 - val_loss: 1.7547 - val_accuracy: 0.3615
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 1.8611 - accuracy: 0.3160INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 447ms/step - loss: 1.8611 - accuracy: 0.3160 - val_loss: 1.6976 - val_accuracy: 0.3994
# Epoch 9/50
# 132/132 [==============================] - 56s 425ms/step - loss: 1.8198 - accuracy: 0.3291 - val_loss: 1.6900 - val_accuracy: 0.3776
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7779 - accuracy: 0.3466INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 436ms/step - loss: 1.7779 - accuracy: 0.3466 - val_loss: 1.5807 - val_accuracy: 0.4383
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 1.7542 - accuracy: 0.3592INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 440ms/step - loss: 1.7542 - accuracy: 0.3592 - val_loss: 1.5559 - val_accuracy: 0.4896
# Epoch 12/50
# 132/132 [==============================] - 58s 442ms/step - loss: 1.7466 - accuracy: 0.3706 - val_loss: 1.5182 - val_accuracy: 0.4507
# Epoch 13/50
# 132/132 [==============================] - 60s 456ms/step - loss: 1.7185 - accuracy: 0.3767 - val_loss: 1.4930 - val_accuracy: 0.4829
# Epoch 14/50
# 132/132 [==============================] - 69s 521ms/step - loss: 1.6774 - accuracy: 0.3855 - val_loss: 1.4799 - val_accuracy: 0.4677
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6592 - accuracy: 0.4064INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 67s 511ms/step - loss: 1.6592 - accuracy: 0.4064 - val_loss: 1.4138 - val_accuracy: 0.5123
# Epoch 16/50
# 132/132 [==============================] - 57s 431ms/step - loss: 1.6510 - accuracy: 0.4035 - val_loss: 1.3832 - val_accuracy: 0.5076
# Epoch 17/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6144 - accuracy: 0.4054INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 450ms/step - loss: 1.6144 - accuracy: 0.4054 - val_loss: 1.3764 - val_accuracy: 0.5228
# Epoch 18/50
# 132/132 [==============================] - 57s 435ms/step - loss: 1.5997 - accuracy: 0.4213 - val_loss: 1.4262 - val_accuracy: 0.4858
# Epoch 19/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5682 - accuracy: 0.4341INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 437ms/step - loss: 1.5682 - accuracy: 0.4341 - val_loss: 1.3333 - val_accuracy: 0.5256
# Epoch 20/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5303 - accuracy: 0.4353INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 1.5303 - accuracy: 0.4353 - val_loss: 1.3258 - val_accuracy: 0.5294
# Epoch 21/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5352 - accuracy: 0.4497INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 448ms/step - loss: 1.5352 - accuracy: 0.4497 - val_loss: 1.3096 - val_accuracy: 0.5351
# Epoch 22/50
# 132/132 [==============================] - 57s 435ms/step - loss: 1.4977 - accuracy: 0.4587 - val_loss: 1.3625 - val_accuracy: 0.5171
# Epoch 23/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4793 - accuracy: 0.4663INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.4793 - accuracy: 0.4663 - val_loss: 1.3416 - val_accuracy: 0.5370
# Epoch 24/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4679 - accuracy: 0.4668INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 451ms/step - loss: 1.4679 - accuracy: 0.4668 - val_loss: 1.2534 - val_accuracy: 0.5626
# Epoch 25/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4540 - accuracy: 0.4765INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 439ms/step - loss: 1.4540 - accuracy: 0.4765 - val_loss: 1.2263 - val_accuracy: 0.5683
# Epoch 26/50
# 132/132 [==============================] - 58s 438ms/step - loss: 1.4417 - accuracy: 0.4768 - val_loss: 1.1806 - val_accuracy: 0.5645
# Epoch 27/50
# 132/132 [==============================] - 58s 436ms/step - loss: 1.4136 - accuracy: 0.4844 - val_loss: 1.2623 - val_accuracy: 0.5522
# Epoch 28/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4043 - accuracy: 0.5059INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 444ms/step - loss: 1.4043 - accuracy: 0.5059 - val_loss: 1.1515 - val_accuracy: 0.5882
# Epoch 29/50
# 132/132 [==============================] - 57s 429ms/step - loss: 1.3774 - accuracy: 0.4938 - val_loss: 1.1941 - val_accuracy: 0.5721
# Epoch 30/50
# 132/132 [==============================] - 58s 437ms/step - loss: 1.3837 - accuracy: 0.4881 - val_loss: 1.1566 - val_accuracy: 0.5873
# Epoch 31/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3506 - accuracy: 0.5116INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.3506 - accuracy: 0.5116 - val_loss: 1.1741 - val_accuracy: 0.5939
# Epoch 32/50
# 132/132 [==============================] - 59s 443ms/step - loss: 1.3460 - accuracy: 0.5178 - val_loss: 1.1347 - val_accuracy: 0.5911
# Epoch 33/50
# 132/132 [==============================] - 57s 428ms/step - loss: 1.3409 - accuracy: 0.5261 - val_loss: 1.1973 - val_accuracy: 0.5825
# Epoch 34/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2926 - accuracy: 0.5325INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 58s 441ms/step - loss: 1.2926 - accuracy: 0.5325 - val_loss: 1.1178 - val_accuracy: 0.5949
# Epoch 35/50
# 132/132 [==============================] - 58s 436ms/step - loss: 1.2998 - accuracy: 0.5301 - val_loss: 1.1512 - val_accuracy: 0.5835
# Epoch 36/50
# 132/132 [==============================] - 57s 429ms/step - loss: 1.3006 - accuracy: 0.5303 - val_loss: 1.1091 - val_accuracy: 0.5844
# Epoch 37/50
# 132/132 [==============================] - 58s 436ms/step - loss: 1.2895 - accuracy: 0.5339 - val_loss: 1.1382 - val_accuracy: 0.5911
# Epoch 38/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2837 - accuracy: 0.5382INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 448ms/step - loss: 1.2837 - accuracy: 0.5382 - val_loss: 1.1130 - val_accuracy: 0.5987
# Epoch 39/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 0.5413INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 444ms/step - loss: 1.2677 - accuracy: 0.5413 - val_loss: 1.0418 - val_accuracy: 0.6357
# Epoch 40/50
# 132/132 [==============================] - 57s 428ms/step - loss: 1.2505 - accuracy: 0.5472 - val_loss: 1.0882 - val_accuracy: 0.6129
# Epoch 41/50
# 132/132 [==============================] - 58s 438ms/step - loss: 1.2441 - accuracy: 0.5453 - val_loss: 1.0486 - val_accuracy: 0.6347
# Epoch 42/50
# 132/132 [==============================] - 57s 431ms/step - loss: 1.2520 - accuracy: 0.5453 - val_loss: 0.9889 - val_accuracy: 0.6205
# Epoch 43/50
# 132/132 [==============================] - 57s 431ms/step - loss: 1.2260 - accuracy: 0.5607 - val_loss: 1.0739 - val_accuracy: 0.6006
# Epoch 44/50
# 132/132 [==============================] - 57s 428ms/step - loss: 1.2191 - accuracy: 0.5503 - val_loss: 1.0485 - val_accuracy: 0.6357
# Epoch 45/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2180 - accuracy: 0.5531INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 59s 449ms/step - loss: 1.2180 - accuracy: 0.5531 - val_loss: 0.9781 - val_accuracy: 0.6490
# Epoch 46/50
# 132/132 [==============================] - 57s 429ms/step - loss: 1.1903 - accuracy: 0.5678 - val_loss: 0.9753 - val_accuracy: 0.6480
# Epoch 47/50
# 132/132 [==============================] - 57s 428ms/step - loss: 1.1791 - accuracy: 0.5766 - val_loss: 1.0132 - val_accuracy: 0.6290
# Epoch 48/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1883 - accuracy: 0.5683INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_sg_thresh/assets
# 132/132 [==============================] - 61s 461ms/step - loss: 1.1883 - accuracy: 0.5683 - val_loss: 0.9923 - val_accuracy: 0.6594
# Epoch 49/50
# 132/132 [==============================] - 57s 429ms/step - loss: 1.1588 - accuracy: 0.5801 - val_loss: 0.9859 - val_accuracy: 0.6461
# Epoch 50/50
# 132/132 [==============================] - 57s 429ms/step - loss: 1.1602 - accuracy: 0.5811 - val_loss: 0.9857 - val_accuracy: 0.6404

# %% [markdown]
# The thresholding model, which did not use transfer learning, performed with a validation accuracy slightly higher than that of the K-Means segmentation.
#
# Notable areas of misclassificationa are:
# * Jacket/Coat
# * Top/Sweater/Dress

# %%
calculate_balanced_acc('model_sg_thresh',clothes_df,imseg_data_path_thresh,'garment_label')
# Out:
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.6309941175679386

# %% [markdown]
# ## Transfer Learning Pattern Model - No Segmentation

# %%
model_vp_noseg = model_function(classes = 8,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,data_path,
                  'pattern_label','training')

test_data = tensor_data(test_gen,clothes_df,data_path,
                  'pattern_label','validation')

checkpoint_model_vp_noseg = checkpoint('model_vp_noseg')

history_vp_noseg = model_vp_noseg.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_noseg,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vp_noseg,'Patterns - No Segmentation, VGG: Accuracy',
              'noseg_pattern_transfer')

plot_confusion_matrix('model_vp_noseg',test_data,
                      'Patterns - No Segmentation, VGG: Confusion Matrix',
                      'noseg_pattern_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 8 classes.
# Found 1054 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0689 - accuracy: 0.6790INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 1184s 9s/step - loss: 1.0689 - accuracy: 0.6790 - val_loss: 0.8208 - val_accuracy: 0.7419
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8794 - accuracy: 0.7323INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 69s 521ms/step - loss: 0.8794 - accuracy: 0.7323 - val_loss: 0.7177 - val_accuracy: 0.7780
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 0.8165 - accuracy: 0.7440INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 67s 508ms/step - loss: 0.8165 - accuracy: 0.7440 - val_loss: 0.5826 - val_accuracy: 0.8065
# Epoch 4/50
# 132/132 [==============================] - 62s 470ms/step - loss: 0.7485 - accuracy: 0.7627 - val_loss: 0.7140 - val_accuracy: 0.7533
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 0.7478 - accuracy: 0.7660INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 69s 524ms/step - loss: 0.7478 - accuracy: 0.7660 - val_loss: 0.5895 - val_accuracy: 0.8188
# Epoch 6/50
# 132/132 [==============================] - 62s 472ms/step - loss: 0.7103 - accuracy: 0.7805 - val_loss: 0.5999 - val_accuracy: 0.8046
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6845 - accuracy: 0.7812INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 68s 515ms/step - loss: 0.6845 - accuracy: 0.7812 - val_loss: 0.5146 - val_accuracy: 0.8397
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 0.6761 - accuracy: 0.8032INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 68s 513ms/step - loss: 0.6761 - accuracy: 0.8032 - val_loss: 0.4377 - val_accuracy: 0.8824
# Epoch 9/50
# 132/132 [==============================] - 63s 476ms/step - loss: 0.6441 - accuracy: 0.8094 - val_loss: 0.5929 - val_accuracy: 0.8548
# Epoch 10/50
# 132/132 [==============================] - 64s 486ms/step - loss: 0.6187 - accuracy: 0.8144 - val_loss: 0.4095 - val_accuracy: 0.8795
# Epoch 11/50
# 132/132 [==============================] - 63s 473ms/step - loss: 0.6148 - accuracy: 0.8163 - val_loss: 0.4330 - val_accuracy: 0.8767
# Epoch 12/50
# 132/132 [==============================] - 63s 473ms/step - loss: 0.5813 - accuracy: 0.8324 - val_loss: 0.4469 - val_accuracy: 0.8605
# Epoch 13/50
# 132/132 [==============================] - 64s 485ms/step - loss: 0.5704 - accuracy: 0.8367 - val_loss: 0.5040 - val_accuracy: 0.8672
# Epoch 14/50
# 132/132 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.8381INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 68s 517ms/step - loss: 0.5707 - accuracy: 0.8381 - val_loss: 0.4130 - val_accuracy: 0.8843
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.8371INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 68s 517ms/step - loss: 0.5599 - accuracy: 0.8371 - val_loss: 0.3511 - val_accuracy: 0.9004
# Epoch 16/50
# 132/132 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.8440INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg/assets
# 132/132 [==============================] - 68s 514ms/step - loss: 0.5469 - accuracy: 0.8440 - val_loss: 0.3468 - val_accuracy: 0.9023
# Epoch 17/50
# 132/132 [==============================] - 63s 475ms/step - loss: 0.5271 - accuracy: 0.8478 - val_loss: 0.4106 - val_accuracy: 0.8852
# Epoch 18/50
# 132/132 [==============================] - 64s 485ms/step - loss: 0.5287 - accuracy: 0.8461 - val_loss: 0.4563 - val_accuracy: 0.8672
# Epoch 19/50
# 132/132 [==============================] - 63s 477ms/step - loss: 0.5320 - accuracy: 0.8471 - val_loss: 0.3933 - val_accuracy: 0.8843
# Epoch 20/50
# 132/132 [==============================] - 62s 470ms/step - loss: 0.5255 - accuracy: 0.8476 - val_loss: 0.4688 - val_accuracy: 0.8757
# Epoch 21/50
# 132/132 [==============================] - 63s 479ms/step - loss: 0.5182 - accuracy: 0.8497 - val_loss: 0.4313 - val_accuracy: 0.8767

# %% [markdown]
# At ~90% validation accuracy, the model that used transfer learning and no image segmentation performed similarly strong to the K-Means segmented model, which achieved ~88% validation accuracy, but which had increasing accuracy as the early stop regularization ended the model.
#
# Notable misclassification areas include polka, checkered and paisley.

# %%
calculate_balanced_acc('model_vp_noseg',clothes_df,data_path,'pattern_label')
# Out:
# Found 1054 non-validated image filenames belonging to 8 classes.
# 0.7506206317566642

# %% [markdown]
# The K-Means model just barely surpassed the non-segmented model in terms of balanced accuracy.

# %% [markdown]
# ## Transfer Learning Model, No Segmentation - Resampled Pattern Data

# %%
model_vp_noseg_r = model_function(classes = 8,alr=.01)

train_data = tensor_data(aug_train_gen,resampled_df,data_path,
                   'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,data_path,
                   'pattern_label','validation')

checkpoint_model_vp_noseg_r = checkpoint('model_vp_noseg_r')

history_vp_noseg_r = model_vp_noseg_r.fit(
     train_data,
     batch_size = 32,
     epochs=50,
     validation_data = test_data,
     callbacks = [checkpoint_model_vp_noseg_r,early_stop],
     validation_batch_size=32
 )

plot_accuracy(history_vp_noseg_r,'Patterns, Resampled - No Segmentation, VGG16: Accuracy',
              'noseg_pattern_transfer_r')

plot_confusion_matrix('model_vp_noseg_r',test_data,
                       'Patterns, Resampled - No Segmentation, VGG16: Confusion Matrix',
                       'noseg_pattern_transfer_r')
# Out:
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 1.6103 - accuracy: 0.4333INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 52s 691ms/step - loss: 1.6103 - accuracy: 0.4333 - val_loss: 1.2389 - val_accuracy: 0.5965
# Epoch 2/50
# 72/72 [==============================] - ETA: 0s - loss: 1.1864 - accuracy: 0.6057INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 49s 689ms/step - loss: 1.1864 - accuracy: 0.6057 - val_loss: 1.3769 - val_accuracy: 0.6435
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9662 - accuracy: 0.7008INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 48s 671ms/step - loss: 0.9662 - accuracy: 0.7008 - val_loss: 1.0632 - val_accuracy: 0.6939
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.7256INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 49s 681ms/step - loss: 0.8959 - accuracy: 0.7256 - val_loss: 1.1373 - val_accuracy: 0.7130
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8901 - accuracy: 0.7247INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 48s 665ms/step - loss: 0.8901 - accuracy: 0.7247 - val_loss: 0.7863 - val_accuracy: 0.8052
# Epoch 6/50
# 72/72 [==============================] - 42s 582ms/step - loss: 0.8268 - accuracy: 0.7538 - val_loss: 0.9353 - val_accuracy: 0.7687
# Epoch 7/50
# 72/72 [==============================] - 41s 562ms/step - loss: 0.7725 - accuracy: 0.7686 - val_loss: 0.8385 - val_accuracy: 0.7774
# Epoch 8/50
# 72/72 [==============================] - 41s 569ms/step - loss: 0.7496 - accuracy: 0.7807 - val_loss: 0.7403 - val_accuracy: 0.8035
# Epoch 9/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7525 - accuracy: 0.7755INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 48s 662ms/step - loss: 0.7525 - accuracy: 0.7755 - val_loss: 0.7551 - val_accuracy: 0.8139
# Epoch 10/50
# 72/72 [==============================] - 41s 563ms/step - loss: 0.7248 - accuracy: 0.7916 - val_loss: 0.7050 - val_accuracy: 0.8104
# Epoch 11/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7081 - accuracy: 0.7950INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_noseg_r/assets
# 72/72 [==============================] - 47s 660ms/step - loss: 0.7081 - accuracy: 0.7950 - val_loss: 0.5220 - val_accuracy: 0.8626
# Epoch 12/50
# 72/72 [==============================] - 42s 581ms/step - loss: 0.6981 - accuracy: 0.7920 - val_loss: 0.6439 - val_accuracy: 0.8191
# Epoch 13/50
# 72/72 [==============================] - 47s 648ms/step - loss: 0.6702 - accuracy: 0.8007 - val_loss: 0.6048 - val_accuracy: 0.8383
# Epoch 14/50
# 72/72 [==============================] - 42s 584ms/step - loss: 0.7068 - accuracy: 0.7920 - val_loss: 0.6286 - val_accuracy: 0.8435
# Epoch 15/50
# 72/72 [==============================] - 41s 570ms/step - loss: 0.6742 - accuracy: 0.7998 - val_loss: 0.6413 - val_accuracy: 0.8243
# Epoch 16/50
# 72/72 [==============================] - 41s 563ms/step - loss: 0.6480 - accuracy: 0.8102 - val_loss: 0.5774 - val_accuracy: 0.8296

# %%
calculate_balanced_acc('model_vp_noseg_r',resampled_df,data_path,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.798437187369585

# %% [markdown]
# The transfer learning model with no segmentation scored considerably better in balanced accuracy on the resampled dataset than the K-Means model, achieving a balanced accuracy score of 79.8% compared to the 75.5% for the K-Means model with 5 clusters.

# %% [markdown]
# ## Transfer Learning Garment Model - No Segmentation

# %%
model_vg_noseg = model_function(classes = 9,alr=.01)

train_data = tensor_data(aug_train_gen,clothes_df,data_path,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,data_path,
                  'garment_label','validation')

checkpoint_model_vg_noseg = checkpoint('model_vg_noseg')

history_vg_noseg = model_vg_noseg.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_noseg,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vg_noseg,'Garments - No Segmentation, VGG: Accuracy',
              'noseg_garment_transfer')

plot_confusion_matrix('model_vg_noseg',test_data,
                      'Garments - No Segmentation, VGG: Confusion Matrix',
                      'noseg_garment_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.9663 - accuracy: 0.2850INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 1229s 9s/step - loss: 1.9663 - accuracy: 0.2850 - val_loss: 2.4517 - val_accuracy: 0.1528
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 1.6762 - accuracy: 0.3862INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 65s 489ms/step - loss: 1.6762 - accuracy: 0.3862 - val_loss: 2.0040 - val_accuracy: 0.3586
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.5568 - accuracy: 0.4298INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 66s 503ms/step - loss: 1.5568 - accuracy: 0.4298 - val_loss: 1.3265 - val_accuracy: 0.5398
# Epoch 4/50
# 132/132 [==============================] - 59s 448ms/step - loss: 1.4718 - accuracy: 0.4642 - val_loss: 1.4254 - val_accuracy: 0.5228
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4221 - accuracy: 0.4910INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 64s 487ms/step - loss: 1.4221 - accuracy: 0.4910 - val_loss: 1.2491 - val_accuracy: 0.5636
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 1.4001 - accuracy: 0.4867INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 66s 499ms/step - loss: 1.4001 - accuracy: 0.4867 - val_loss: 1.0082 - val_accuracy: 0.6271
# Epoch 7/50
# 132/132 [==============================] - 59s 445ms/step - loss: 1.3423 - accuracy: 0.5142 - val_loss: 1.0233 - val_accuracy: 0.6233
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 1.3351 - accuracy: 0.5318INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 66s 496ms/step - loss: 1.3351 - accuracy: 0.5318 - val_loss: 1.0044 - val_accuracy: 0.6300
# Epoch 9/50
# 132/132 [==============================] - 59s 443ms/step - loss: 1.2993 - accuracy: 0.5360 - val_loss: 1.0466 - val_accuracy: 0.6205
# Epoch 10/50
# 132/132 [==============================] - 58s 442ms/step - loss: 1.2669 - accuracy: 0.5441 - val_loss: 1.0994 - val_accuracy: 0.6129
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2866 - accuracy: 0.5583INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 65s 489ms/step - loss: 1.2866 - accuracy: 0.5583 - val_loss: 0.9142 - val_accuracy: 0.6850
# Epoch 12/50
# 132/132 [==============================] - 59s 443ms/step - loss: 1.2491 - accuracy: 0.5685 - val_loss: 0.9279 - val_accuracy: 0.6603
# Epoch 13/50
# 132/132 [==============================] - 59s 448ms/step - loss: 1.2499 - accuracy: 0.5721 - val_loss: 0.8837 - val_accuracy: 0.6822
# Epoch 14/50
# 132/132 [==============================] - 60s 451ms/step - loss: 1.2357 - accuracy: 0.5697 - val_loss: 1.0502 - val_accuracy: 0.6518
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2010 - accuracy: 0.5910INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 64s 483ms/step - loss: 1.2010 - accuracy: 0.5910 - val_loss: 0.8526 - val_accuracy: 0.6945
# Epoch 16/50
# 132/132 [==============================] - 59s 443ms/step - loss: 1.2155 - accuracy: 0.5744 - val_loss: 0.9087 - val_accuracy: 0.6774
# Epoch 17/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2065 - accuracy: 0.5853INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 65s 491ms/step - loss: 1.2065 - accuracy: 0.5853 - val_loss: 0.8807 - val_accuracy: 0.6954
# Epoch 18/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2129 - accuracy: 0.5808INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 65s 489ms/step - loss: 1.2129 - accuracy: 0.5808 - val_loss: 0.8248 - val_accuracy: 0.7125
# Epoch 19/50
# 132/132 [==============================] - 59s 444ms/step - loss: 1.1815 - accuracy: 0.6060 - val_loss: 0.8693 - val_accuracy: 0.6907
# Epoch 20/50
# 132/132 [==============================] - 60s 451ms/step - loss: 1.1683 - accuracy: 0.6072 - val_loss: 1.0054 - val_accuracy: 0.6632
# Epoch 21/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1731 - accuracy: 0.6050INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 64s 482ms/step - loss: 1.1731 - accuracy: 0.6050 - val_loss: 0.8615 - val_accuracy: 0.7135
# Epoch 22/50
# 132/132 [==============================] - 58s 443ms/step - loss: 1.1573 - accuracy: 0.6048 - val_loss: 0.8843 - val_accuracy: 0.6803
# Epoch 23/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.6143INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_noseg/assets
# 132/132 [==============================] - 65s 494ms/step - loss: 1.1538 - accuracy: 0.6143 - val_loss: 0.8303 - val_accuracy: 0.7211

# %%
calculate_balanced_acc('model_vg_noseg',clothes_df,data_path,'garment_label')
# Out:
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.7043030971113807

# %% [markdown]
# The model that uses no image segmentation and transfer learning performs best out of the garment classifiers. The epoch with the best validation accuracy achieved an accuracy of 72.11%, and a balanced accuracy of 70.4%. Notable areas of misclassification are:
#
# * Coat/Jacket
# * Dress/Top

# %% [markdown]
# ## Transfer Learning Model, No Segmentation, Less Augmentation - Resampled Pattern Data

# %%
model_vp_nsa_r = model_function(classes = 8,alr=.01)

train_data = tensor_data(la_train_gen,resampled_df,data_path,
                  'pattern_label','training')

test_data = tensor_data(test_gen,resampled_df,data_path,
                  'pattern_label','validation')

checkpoint_model_vp_nsa_r = checkpoint('model_vp_nsa_r')

history_vp_nsa_r = model_vp_nsa_r.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vp_nsa_r,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vp_nsa_r,'Patterns, Resampled - No Segmentation, Low Augmentation VGG16: Accuracy',
              'nsa_pattern_transfer_r')

plot_confusion_matrix('model_vp_nsa_r',test_data,
                      'Patterns, Resampled - No Segmentation, Low Augmentation VGG16: Confusion Matrix',
                      'nsa_pattern_transfer_r')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Found 2303 non-validated image filenames belonging to 8 classes.
# Found 575 non-validated image filenames belonging to 8 classes.
# Epoch 1/50
# 72/72 [==============================] - ETA: 0s - loss: 1.5184 - accuracy: 0.4690 INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 1132s 16s/step - loss: 1.5184 - accuracy: 0.4690 - val_loss: 1.4199 - val_accuracy: 0.5878
# Epoch 2/50
# 72/72 [==============================] - 39s 547ms/step - loss: 1.0714 - accuracy: 0.6422 - val_loss: 4.1174 - val_accuracy: 0.4052
# Epoch 3/50
# 72/72 [==============================] - ETA: 0s - loss: 0.9259 - accuracy: 0.7112INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 46s 638ms/step - loss: 0.9259 - accuracy: 0.7112 - val_loss: 1.3871 - val_accuracy: 0.5913
# Epoch 4/50
# 72/72 [==============================] - ETA: 0s - loss: 0.8412 - accuracy: 0.7403INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 46s 644ms/step - loss: 0.8412 - accuracy: 0.7403 - val_loss: 1.1512 - val_accuracy: 0.6765
# Epoch 5/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7806 - accuracy: 0.7616INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 48s 668ms/step - loss: 0.7806 - accuracy: 0.7616 - val_loss: 0.7511 - val_accuracy: 0.7757
# Epoch 6/50
# 72/72 [==============================] - 40s 549ms/step - loss: 0.7491 - accuracy: 0.7746 - val_loss: 1.1482 - val_accuracy: 0.7374
# Epoch 7/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7130 - accuracy: 0.7842INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 46s 640ms/step - loss: 0.7130 - accuracy: 0.7842 - val_loss: 0.7940 - val_accuracy: 0.8087
# Epoch 8/50
# 72/72 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.7946INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 47s 658ms/step - loss: 0.7052 - accuracy: 0.7946 - val_loss: 0.6223 - val_accuracy: 0.8400
# Epoch 9/50
# 72/72 [==============================] - 40s 550ms/step - loss: 0.6818 - accuracy: 0.8055 - val_loss: 0.6775 - val_accuracy: 0.8052
# Epoch 10/50
# 72/72 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.8085INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 46s 641ms/step - loss: 0.6429 - accuracy: 0.8085 - val_loss: 0.5758 - val_accuracy: 0.8522
# Epoch 11/50
# 72/72 [==============================] - 41s 570ms/step - loss: 0.6301 - accuracy: 0.8298 - val_loss: 0.6731 - val_accuracy: 0.8261
# Epoch 12/50
# 72/72 [==============================] - 40s 551ms/step - loss: 0.5871 - accuracy: 0.8302 - val_loss: 0.6288 - val_accuracy: 0.8330
# Epoch 13/50
# 72/72 [==============================] - 39s 546ms/step - loss: 0.5817 - accuracy: 0.8398 - val_loss: 0.7587 - val_accuracy: 0.8191
# Epoch 14/50
# 72/72 [==============================] - 39s 545ms/step - loss: 0.5735 - accuracy: 0.8359 - val_loss: 0.5503 - val_accuracy: 0.8348
# Epoch 15/50
# 72/72 [==============================] - 39s 548ms/step - loss: 0.5857 - accuracy: 0.8281 - val_loss: 0.5820 - val_accuracy: 0.8435
# Epoch 16/50
# 72/72 [==============================] - 40s 554ms/step - loss: 0.5342 - accuracy: 0.8441 - val_loss: 0.6426 - val_accuracy: 0.8504
# Epoch 17/50
# 72/72 [==============================] - 40s 551ms/step - loss: 0.5260 - accuracy: 0.8454 - val_loss: 0.6576 - val_accuracy: 0.8365
# Epoch 18/50
# 72/72 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.8545INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vp_nsa_r/assets
# 72/72 [==============================] - 48s 673ms/step - loss: 0.5089 - accuracy: 0.8545 - val_loss: 0.5607 - val_accuracy: 0.8609
# Epoch 19/50
# 72/72 [==============================] - 40s 554ms/step - loss: 0.5431 - accuracy: 0.8446 - val_loss: 0.8282 - val_accuracy: 0.7878

# %%
calculate_balanced_acc('model_vp_nsa_r',resampled_df,data_path,'pattern_label')
# Out:
# Found 575 non-validated image filenames belonging to 8 classes.
# 0.7956484544847529

# %% [markdown]
# When fewer augmentations were applied to the non-segmented image data, and fed into the transfer learning model, performance relative to the model that was fed more augmented image data was fairly negilible.
#
# The confusion matrices are very similar.

# %% [markdown]
# ## Transfer Learning - Garment Model, No Segmentation, Less Augmentation

# %%
model_vg_nsa = model_function(classes = 9,alr=.01)

train_data = tensor_data(la_train_gen,clothes_df,data_path,
                  'garment_label','training')

test_data = tensor_data(test_gen,clothes_df,data_path,
                  'garment_label','validation')

checkpoint_model_vg_nsa = checkpoint('model_vg_nsa')

history_vg_nsa = model_vg_nsa.fit(
    train_data,
    batch_size = 32,
    epochs=50,
    validation_data = test_data,
    callbacks = [checkpoint_model_vg_nsa,early_stop],
    validation_batch_size=32
)

plot_accuracy(history_vg_nsa,'Garments - No Segmentation, Less Augmentation VGG: Accuracy',
              'nsa_garment_transfer')

plot_confusion_matrix('model_vg_nsa',test_data,
                      'Garments - No Segmentation, Less Augmentation VGG: Confusion Matrix',
                      'nsa_garment_transfer')
# Out:
# Found 4218 non-validated image filenames belonging to 9 classes.
# Found 1054 non-validated image filenames belonging to 9 classes.
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 1.8249 - accuracy: 0.3385INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 1221s 9s/step - loss: 1.8249 - accuracy: 0.3385 - val_loss: 1.5088 - val_accuracy: 0.4326
# Epoch 2/50
# 132/132 [==============================] - 72s 546ms/step - loss: 1.4326 - accuracy: 0.4891 - val_loss: 1.6347 - val_accuracy: 0.4165
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 1.2886 - accuracy: 0.5436INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 80s 606ms/step - loss: 1.2886 - accuracy: 0.5436 - val_loss: 0.9692 - val_accuracy: 0.6679
# Epoch 4/50
# 132/132 [==============================] - 74s 557ms/step - loss: 1.1649 - accuracy: 0.5920 - val_loss: 0.9951 - val_accuracy: 0.6414
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1432 - accuracy: 0.5982INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 82s 618ms/step - loss: 1.1432 - accuracy: 0.5982 - val_loss: 0.9569 - val_accuracy: 0.6926
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 1.1062 - accuracy: 0.6211INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 80s 605ms/step - loss: 1.1062 - accuracy: 0.6211 - val_loss: 0.8256 - val_accuracy: 0.7173
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0409 - accuracy: 0.6392INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 81s 616ms/step - loss: 1.0409 - accuracy: 0.6392 - val_loss: 0.7905 - val_accuracy: 0.7296
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 1.0371 - accuracy: 0.6501INFO:tensorflow:Assets written to: /content/drive/MyDrive/clothing_class/model_folder/model_vg_nsa/assets
# 132/132 [==============================] - 84s 640ms/step - loss: 1.0371 - accuracy: 0.6501 - val_loss: 0.7670 - val_accuracy: 0.7533
# Epoch 9/50
# 132/132 [==============================] - 74s 559ms/step - loss: 1.0009 - accuracy: 0.6569 - val_loss: 0.9044 - val_accuracy: 0.7049
# Epoch 10/50
# 132/132 [==============================] - 71s 540ms/step - loss: 0.9885 - accuracy: 0.6693 - val_loss: 0.7763 - val_accuracy: 0.7400
# Epoch 11/50
# 132/132 [==============================] - 77s 580ms/step - loss: 0.9511 - accuracy: 0.6818 - val_loss: 0.7726 - val_accuracy: 0.7372
# Epoch 12/50
# 132/132 [==============================] - 74s 564ms/step - loss: 0.9406 - accuracy: 0.6849 - val_loss: 0.9284 - val_accuracy: 0.7040
# Epoch 13/50
# 132/132 [==============================] - 72s 542ms/step - loss: 0.9264 - accuracy: 0.6906 - val_loss: 0.8107 - val_accuracy: 0.7410

# %%
calculate_balanced_acc('model_vg_nsa',clothes_df,data_path,'garment_label')
# Out:
# Found 1054 non-validated image filenames belonging to 9 classes.
# 0.7363810863024891

# %% [markdown]
# A model with less augmentation, using no segmentation, had the best balanced accuracy score on the garment data, with a score of 73.63%.
